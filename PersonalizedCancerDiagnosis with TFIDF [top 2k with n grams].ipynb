# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")
from mlxtend.classifier import StackingClassifier
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 200.35586447552126 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.429030526068535
# Log loss on Test Data using Random Model 2.4656087648586116
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 237
# BRCA1     170
# TP53      104
# EGFR       98
# PTEN       88
# BRCA2      86
# KIT        61
# BRAF       60
# ERBB2      45
# PIK3CA     44
# ALK        40
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 237 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(max_features=2000, ngram_range=(1, 4))
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2069       TET2
# 1828    PPP2R1A
# 682      CDKN2A
# 1295       HRAS
# 1967     CTNNB1
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl1',
#  'asxl2',
#  'atm',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axl',
#  'b2m',
#  'bap1',
#  'bard1',
#  'bcl10',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'cebpa',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'epcam',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'errfi1',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fam58a',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf19',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxo1',
#  'gata3',
#  'gli1',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5a',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'klf4',
#  'kmt2a',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'myod1',
#  'ncor1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppm1d',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51c',
#  'rad51d',
#  'rad54l',
#  'raf1',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rictor',
#  'rit1',
#  'rnf43',
#  'ros1',
#  'runx1',
#  'rxra',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'sf3b1',
#  'shoc2',
#  'shq1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'srsf2',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tcf7l2',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vegfa',
#  'vhl',
#  'whsc1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 236)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.4334583965269967
# For values of alpha =  0.0001 The log loss is: 1.2371387652284507
# For values of alpha =  0.001 The log loss is: 1.2507978806134534
# For values of alpha =  0.01 The log loss is: 1.349123550891852
# For values of alpha =  0.1 The log loss is: 1.438436232769021
# For values of alpha =  1 The log loss is: 1.471385772932978
# For values of best alpha =  0.0001 The train log loss is: 1.0369756255469633
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2371387652284507
# For values of best alpha =  0.0001 The test log loss is: 1.2686403892040317

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  237  genes in train dataset?
# Ans
# 1. In test data 644 out of 665 : 96.84210526315789
# 2. In cross validation data 518 out of  532 : 97.36842105263158

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1928
# Truncating_Mutations    58
# Deletion                51
# Amplification           49
# Fusions                 18
# Overexpression           5
# G12V                     3
# Q209L                    2
# Q61H                     2
# G12S                     2
# I31M                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1928 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02730697 0.05131827 0.07438795 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(max_features=2000, ngram_range=(1, 4))
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 2000)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.741101051291195
# For values of alpha =  0.0001 The log loss is: 1.7263766112915009
# For values of alpha =  0.001 The log loss is: 1.7365540075281196
# For values of alpha =  0.01 The log loss is: 1.74850006535762
# For values of alpha =  0.1 The log loss is: 1.7553617528253749
# For values of alpha =  1 The log loss is: 1.7572597410451125
# For values of best alpha =  0.0001 The train log loss is: 0.7896901702902585
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7263766112915009
# For values of best alpha =  0.0001 The test log loss is: 1.696953821469915

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1928  genes in test and cross validation data sets?
# Ans
# 1. In test data 77 out of 665 : 11.578947368421053
# 2. In cross validation data 45 out of  532 : 8.458646616541353

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a TfidfVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(min_df=3, max_features=2000, ngram_range=(1, 4))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 2000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({8.231892527665398: 6, 12.3478387914981: 5, 6.547983033345942: 3, 6.30227173680338: 3, 9.579349498990174: 2, 9.217863454375319: 2, 8.645290510792943: 2, 8.612188906489834: 2, 8.153532938120515: 2, 7.715934555151647: 2, 7.345872345703389: 2, 6.850622545168427: 2, 6.578339570321586: 2, 6.574901653916899: 2, 6.56077192950203: 2, 6.399157736752624: 2, 218.76879851128842: 1, 144.37144567707608: 1, 119.91003503722948: 1, 110.21699342113396: 1, 102.78914241518073: 1, 98.22614728298949: 1, 93.83966950738609: 1, 93.44054353123464: 1, 93.210298425077: 1, 91.97471084676766: 1, 90.71756043213442: 1, 87.87577056335263: 1, 76.42477748633462: 1, 75.12873460926754: 1, 74.61404758709831: 1, 74.48553139684373: 1, 72.08033826777994: 1, 66.7944558183796: 1, 66.4367146528659: 1, 66.00642914097187: 1, 63.833201637767495: 1, 63.175617033478574: 1, 60.68535544900584: 1, 59.31599207456392: 1, 57.98338243678606: 1, 56.04919003451607: 1, 55.62675996970036: 1, 55.60765523467487: 1, 55.26160420560818: 1, 55.12492289161338: 1, 52.419291644929885: 1, 52.41833340150467: 1, 52.10942129779896: 1, 51.2513640998832: 1, 50.53418654247645: 1, 50.079313400631044: 1, 49.55314819546285: 1, 48.73724977160781: 1, 47.86263016010868: 1, 47.17327836156476: 1, 46.687306500360116: 1, 44.08700493346381: 1, 43.20393911539323: 1, 42.73376471373667: 1, 42.5835921807298: 1, 41.756727821658274: 1, 41.32391055813227: 1, 40.161180389749525: 1, 38.97761639785769: 1, 38.383512879245984: 1, 37.890552857225224: 1, 37.8598907187829: 1, 37.44254803942103: 1, 37.42479302151855: 1, 36.52795811952198: 1, 36.498333869735795: 1, 36.23609325799218: 1, 35.798312136457355: 1, 35.71354850831965: 1, 35.472621088559265: 1, 35.31877434008498: 1, 35.24471236353163: 1, 35.11473573327824: 1, 34.634978105441746: 1, 34.57638188608852: 1, 34.239276919716545: 1, 34.221627673447074: 1, 33.89328303562442: 1, 33.553148307888414: 1, 33.10711929145661: 1, 33.03444434691594: 1, 33.014710029149285: 1, 32.88852418143584: 1, 32.77539189282617: 1, 32.39030295814695: 1, 32.2559106835566: 1, 32.170450274782354: 1, 32.168590880943405: 1, 31.38066357402445: 1, 30.339742732541414: 1, 30.13839922256388: 1, 29.99872162288151: 1, 29.97666895594523: 1, 29.811190144709112: 1, 29.73297542109035: 1, 29.68857876230884: 1, 29.61450619188499: 1, 29.57130137402146: 1, 29.555584938924852: 1, 29.433947451227912: 1, 29.329560205303522: 1, 29.09336725492392: 1, 28.6950866240139: 1, 28.03772584504908: 1, 27.910846519638515: 1, 27.79817853302393: 1, 27.544326015769556: 1, 27.458695401836824: 1, 27.192883957843158: 1, 27.145200801043387: 1, 27.041175506228036: 1, 27.035747826362858: 1, 27.00852383196474: 1, 26.597549820601728: 1, 26.379547494292073: 1, 26.26826474171661: 1, 26.23406364692895: 1, 26.21647255389339: 1, 26.139618641855318: 1, 26.135465059137548: 1, 26.10193771970342: 1, 26.03638291550887: 1, 26.02639418561571: 1, 25.993700573248002: 1, 25.97418048746836: 1, 25.76657223919547: 1, 25.541258755745964: 1, 25.53574882480654: 1, 25.518332364663014: 1, 25.2656124147482: 1, 25.236537365506276: 1, 25.110990234103355: 1, 24.972312005863007: 1, 24.949394997473203: 1, 24.92862418911412: 1, 24.731691182932995: 1, 24.63877469427492: 1, 24.611099731448753: 1, 24.594666069728447: 1, 24.336852433531103: 1, 24.308352405234213: 1, 24.28471046915141: 1, 24.129165512118757: 1, 24.122643762042838: 1, 24.11356962949736: 1, 24.07943234432925: 1, 23.959699771510817: 1, 23.929595839518875: 1, 23.881339204419074: 1, 23.679042817606916: 1, 23.636757470863: 1, 23.607103890738014: 1, 23.583150081233978: 1, 23.432458244786766: 1, 23.22885529326638: 1, 23.001374378528187: 1, 22.921722690385135: 1, 22.823401400061773: 1, 22.820465512134344: 1, 22.719610226184514: 1, 22.274305056760657: 1, 22.22505361325375: 1, 22.132523721644684: 1, 22.04148070444609: 1, 21.788892178230054: 1, 21.685486467591957: 1, 21.613756955779223: 1, 21.465111569467318: 1, 21.409081579913433: 1, 21.372176022536152: 1, 21.32066836843421: 1, 21.198449903632593: 1, 21.133316713865 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1057385799355608
# For values of alpha =  0.0001 The log loss is: 1.0877025558381388
# For values of alpha =  0.001 The log loss is: 1.3068248412785757
# For values of alpha =  0.01 The log loss is: 1.5240976824490136
# For values of alpha =  0.1 The log loss is: 1.9490350707987034
# For values of alpha =  1 The log loss is: 1.9637988215307771
# For values of best alpha =  0.0001 The train log loss is: 0.7364508927494012
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0877025558381388
# For values of best alpha =  0.0001 The test log loss is: 1.1736098139888973

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(min_df=3, max_features=2000, ngram_range=(1, 4))
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 93.15 % of word of test data appeared in train data
# 93.4 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=2000, ngram_range=(1, 4))
    var_count_vec = TfidfVectorizer(max_features=2000, ngram_range=(1, 4))
    text_count_vec = TfidfVectorizer(min_df=3, max_features=2000, ngram_range=(1, 4))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 4236)
# (number of data points * number of features) in test data =  (665, 4236)
# (number of data points * number of features) in cross validation data = (532, 4236)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2328187144831952
# for alpha = 0.0001
# Log Loss : 1.2331173273966598
# for alpha = 0.001
# Log Loss : 1.2343571497077486
# for alpha = 0.1
# Log Loss : 1.256379333878888
# for alpha = 1
# Log Loss : 1.3095683187937168
# for alpha = 10
# Log Loss : 1.4768562224411907
# for alpha = 100
# Log Loss : 1.4846062638954574
# for alpha = 1000
# Log Loss : 1.4691217417026337
# For values of best alpha =  1e-05 The train log loss is: 0.5802627071884126
# For values of best alpha =  1e-05 The cross validation log loss is: 1.2328187144831952
# For values of best alpha =  1e-05 The test log loss is: 1.1771831262707886

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.2328187144831952
# Number of missclassified point : 0.40037593984962405
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0624 0.0533 0.014  0.0778 0.0354 0.0368 0.714  0.0036 0.0026]]
# Actual Class : 7
# --------------------------------------------------
# 15 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 19 Text feature [cells] present in test data point [True]
# 20 Text feature [kinase] present in test data point [True]
# 21 Text feature [factor] present in test data point [True]
# 23 Text feature [expressing] present in test data point [True]
# 24 Text feature [inhibitor] present in test data point [True]
# 25 Text feature [contrast] present in test data point [True]
# 26 Text feature [independent] present in test data point [True]
# 27 Text feature [growth] present in test data point [True]
# 28 Text feature [signaling] present in test data point [True]
# 29 Text feature [also] present in test data point [True]
# 30 Text feature [presence] present in test data point [True]
# 31 Text feature [however] present in test data point [True]
# 32 Text feature [cell] present in test data point [True]
# 33 Text feature [shown] present in test data point [True]
# 35 Text feature [sensitive] present in test data point [True]
# 36 Text feature [treated] present in test data point [True]
# 37 Text feature [10] present in test data point [True]
# 38 Text feature [treatment] present in test data point [True]
# 39 Text feature [similar] present in test data point [True]
# 40 Text feature [phosphorylation] present in test data point [True]
# 41 Text feature [addition] present in test data point [True]
# 43 Text feature [compared] present in test data point [True]
# 44 Text feature [suggest] present in test data point [True]
# 45 Text feature [inhibitors] present in test data point [True]
# 46 Text feature [constitutive] present in test data point [True]
# 47 Text feature [activating] present in test data point [True]
# 48 Text feature [well] present in test data point [True]
# 49 Text feature [constitutively] present in test data point [True]
# 50 Text feature [concentrations] present in test data point [True]
# 52 Text feature [inhibited] present in test data point [True]
# 53 Text feature [higher] present in test data point [True]
# 54 Text feature [may] present in test data point [True]
# 55 Text feature [previously] present in test data point [True]
# 56 Text feature [mechanism] present in test data point [True]
# 57 Text feature [mutations] present in test data point [True]
# 58 Text feature [inhibition] present in test data point [True]
# 59 Text feature [increased] present in test data point [True]
# 60 Text feature [recently] present in test data point [True]
# 62 Text feature [potential] present in test data point [True]
# 63 Text feature [mutant] present in test data point [True]
# 64 Text feature [antibodies] present in test data point [True]
# 65 Text feature [3b] present in test data point [True]
# 66 Text feature [absence] present in test data point [True]
# 67 Text feature [enhanced] present in test data point [True]
# 69 Text feature [oncogenic] present in test data point [True]
# 70 Text feature [showed] present in test data point [True]
# 71 Text feature [figure] present in test data point [True]
# 72 Text feature [found] present in test data point [True]
# 73 Text feature [results] present in test data point [True]
# 74 Text feature [described] present in test data point [True]
# 75 Text feature [increase] present in test data point [True]
# 76 Text feature [tyrosine] present in test data point [True]
# 77 Text feature [interestingly] present in test data point [True]
# 78 Text feature [pathways] present in test data point [True]
# 79 Text feature [although] present in test data point [True]
# 81 Text feature [total] present in test data point [True]
# 82 Text feature [1a] present in test data point [True]
# 83 Text feature [could] present in test data point [True]
# 84 Text feature [observed] present in test data point [True]
# 85 Text feature [different] present in test data point [True]
# 86 Text feature [3a] present in test data point [True]
# 87 Text feature [proliferation] present in test data point [True]
# 88 Text feature [without] present in test data point [True]
# 89 Text feature [activate] present in test data point [True]
# 90 Text feature [either] present in test data point [True]
# 91 Text feature [including] present in test data point [True]
# 92 Text feature [various] present in test data point [True]
# 93 Text feature [consistent] present in test data point [True]
# 94 Text feature [serum] present in test data point [True]
# 95 Text feature [using] present in test data point [True]
# 96 Text feature [examined] present in test data point [True]
# 97 Text feature [mutation] present in test data point [True]
# 98 Text feature [followed] present in test data point [True]
# 99 Text feature [studies] present in test data point [True]
# Out of the top  100  features  77 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.0799 0.0665 0.0152 0.0988 0.044  0.0466 0.1181 0.0154 0.5153]]
# Actual Class : 9
# --------------------------------------------------
# 1 Text feature [sf3b1] present in test data point [True]
# 4 Text feature [splicing] present in test data point [True]
# 5 Text feature [differential] present in test data point [True]
# 9 Text feature [aberrant] present in test data point [True]
# 10 Text feature [alternative] present in test data point [True]
# 11 Text feature [mds] present in test data point [True]
# 13 Text feature [ezh2] present in test data point [True]
# 14 Text feature [rna] present in test data point [True]
# 15 Text feature [splice] present in test data point [True]
# 18 Text feature [pre] present in test data point [True]
# 19 Text feature [seq] present in test data point [True]
# 48 Text feature [samples] present in test data point [True]
# 49 Text feature [events] present in test data point [True]
# 50 Text feature [consequences] present in test data point [True]
# 51 Text feature [mutant] present in test data point [True]
# 54 Text feature [observed] present in test data point [True]
# 56 Text feature [limited] present in test data point [True]
# 58 Text feature [knockdown] present in test data point [True]
# 59 Text feature [specific] present in test data point [True]
# 60 Text feature [different] present in test data point [True]
# 63 Text feature [sequences] present in test data point [True]
# 66 Text feature [series] present in test data point [True]
# 68 Text feature [genes] present in test data point [True]
# 70 Text feature [sites] present in test data point [True]
# 71 Text feature [generate] present in test data point [True]
# 72 Text feature [mrna] present in test data point [True]
# 74 Text feature [biological] present in test data point [True]
# 75 Text feature [intron] present in test data point [True]
# 78 Text feature [expressed] present in test data point [True]
# 79 Text feature [pattern] present in test data point [True]
# 83 Text feature [sample] present in test data point [True]
# 85 Text feature [using] present in test data point [True]
# 88 Text feature [alter] present in test data point [True]
# 90 Text feature [rather] present in test data point [True]
# 91 Text feature [array] present in test data point [True]
# 95 Text feature [targets] present in test data point [True]
# 96 Text feature [finally] present in test data point [True]
# 97 Text feature [compared] present in test data point [True]
# 98 Text feature [positions] present in test data point [True]
# Out of the top  100  features  39 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0473936896112606
# for alpha = 11
# Log Loss : 1.0466900512663093
# for alpha = 15
# Log Loss : 1.058049881425538
# for alpha = 21
# Log Loss : 1.0686712964723368
# for alpha = 31
# Log Loss : 1.0924500952358236
# for alpha = 41
# Log Loss : 1.1040325191887967
# for alpha = 51
# Log Loss : 1.1117962957536514
# for alpha = 99
# Log Loss : 1.149053198713328
# For values of best alpha =  11 The train log loss is: 0.6277495248971137
# For values of best alpha =  11 The cross validation log loss is: 1.0466900512663093
# For values of best alpha =  11 The test log loss is: 1.124053793172333

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0466900512663093
# Number of mis-classified points : 0.37781954887218044
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# The  11  nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 7 7 7]
# Fequency of nearest points : Counter({7: 11})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 5
# Actual Class : 4
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [4 5 5 4 5 4 1 5 6 4 1]
# Fequency of nearest points : Counter({4: 4, 5: 4, 1: 2, 6: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.121329536502501
# for alpha = 1e-05
# Log Loss : 1.1033229327173015
# for alpha = 0.0001
# Log Loss : 1.0269021441275452
# for alpha = 0.001
# Log Loss : 1.0543583566429031
# for alpha = 0.01
# Log Loss : 1.1915564515726211
# for alpha = 0.1
# Log Loss : 1.7453495114555941
# for alpha = 1
# Log Loss : 1.8744038898137585
# for alpha = 10
# Log Loss : 1.8871285377928082
# for alpha = 100
# Log Loss : 1.8885900853217625
# For values of best alpha =  0.0001 The train log loss is: 0.4590247360923507
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0269021441275452
# For values of best alpha =  0.0001 The test log loss is: 0.9430644234453383

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0269021441275452
# Number of mis-classified points : 0.34398496240601506
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0106 0.0255 0.0405 0.0099 0.023  0.0062 0.8805 0.0028 0.001 ]]
# Actual Class : 7
# --------------------------------------------------
# 11 Text feature [intrinsic] present in test data point [True]
# 28 Text feature [insertion] present in test data point [True]
# 32 Text feature [transformed] present in test data point [True]
# 33 Text feature [thyroid] present in test data point [True]
# 34 Text feature [downstream] present in test data point [True]
# 40 Text feature [tk] present in test data point [True]
# 45 Text feature [murine] present in test data point [True]
# 47 Text feature [protocol] present in test data point [True]
# 50 Text feature [oncogene] present in test data point [True]
# 55 Text feature [increases] present in test data point [True]
# 69 Text feature [activated] present in test data point [True]
# 73 Text feature [extracellular] present in test data point [True]
# 75 Text feature [concentrations] present in test data point [True]
# 81 Text feature [constitutive] present in test data point [True]
# 82 Text feature [activation] present in test data point [True]
# 83 Text feature [immunoblot] present in test data point [True]
# 85 Text feature [akt] present in test data point [True]
# 89 Text feature [overexpression] present in test data point [True]
# 93 Text feature [segment] present in test data point [True]
# 116 Text feature [oncogenic] present in test data point [True]
# 123 Text feature [factor] present in test data point [True]
# 133 Text feature [ligand] present in test data point [True]
# 135 Text feature [heterogeneity] present in test data point [True]
# 136 Text feature [untreated] present in test data point [True]
# 137 Text feature [oncogenes] present in test data point [True]
# 139 Text feature [cross] present in test data point [True]
# 146 Text feature [minutes] present in test data point [True]
# 159 Text feature [bp] present in test data point [True]
# 161 Text feature [extent] present in test data point [True]
# 175 Text feature [enhanced] present in test data point [True]
# 177 Text feature [inhibited] present in test data point [True]
# 178 Text feature [ligands] present in test data point [True]
# 193 Text feature [lesions] present in test data point [True]
# 195 Text feature [pathways] present in test data point [True]
# 201 Text feature [catenin] present in test data point [True]
# 209 Text feature [lipid] present in test data point [True]
# 210 Text feature [transforming] present in test data point [True]
# 219 Text feature [signaling] present in test data point [True]
# 222 Text feature [adenocarcinoma] present in test data point [True]
# 235 Text feature [3t3] present in test data point [True]
# 241 Text feature [phospho] present in test data point [True]
# 244 Text feature [injected] present in test data point [True]
# 246 Text feature [induces] present in test data point [True]
# 248 Text feature [phosphorylated] present in test data point [True]
# 249 Text feature [fragment] present in test data point [True]
# 253 Text feature [coding] present in test data point [True]
# 255 Text feature [itd] present in test data point [True]
# 260 Text feature [3b] present in test data point [True]
# 265 Text feature [means] present in test data point [True]
# 271 Text feature [leading] present in test data point [True]
# 272 Text feature [approximately] present in test data point [True]
# 279 Text feature [expressing] present in test data point [True]
# 292 Text feature [homology] present in test data point [True]
# 296 Text feature [transformation] present in test data point [True]
# 301 Text feature [ras] present in test data point [True]
# 305 Text feature [stably] present in test data point [True]
# 308 Text feature [event] present in test data point [True]
# 311 Text feature [inhibits] present in test data point [True]
# 315 Text feature [gfp] present in test data point [True]
# 316 Text feature [marrow] present in test data point [True]
# 317 Text feature [clearly] present in test data point [True]
# 319 Text feature [500] present in test data point [True]
# 324 Text feature [regulated] present in test data point [True]
# 325 Text feature [colonies] present in test data point [True]
# 326 Text feature [bone] present in test data point [True]
# 329 Text feature [display] present in test data point [True]
# 340 Text feature [codon] present in test data point [True]
# 341 Text feature [moreover] present in test data point [True]
# 342 Text feature [codons] present in test data point [True]
# 343 Text feature [hematopoietic] present in test data point [True]
# 347 Text feature [approved] present in test data point [True]
# 354 Text feature [prognostic] present in test data point [True]
# 356 Text feature [increased] present in test data point [True]
# 362 Text feature [effectors] present in test data point [True]
# 363 Text feature [serine] present in test data point [True]
# 364 Text feature [distinct] present in test data point [True]
# 367 Text feature [epithelial] present in test data point [True]
# 373 Text feature [phosphorylation] present in test data point [True]
# 375 Text feature [promoting] present in test data point [True]
# 377 Text feature [presence] present in test data point [True]
# 387 Text feature [alteration] present in test data point [True]
# 394 Text feature [activate] present in test data point [True]
# 398 Text feature [acute] present in test data point [True]
# 405 Text feature [receptors] present in test data point [True]
# 406 Text feature [per] present in test data point [True]
# 407 Text feature [de] present in test data point [True]
# 409 Text feature [metastasis] present in test data point [True]
# 417 Text feature [conditions] present in test data point [True]
# 419 Text feature [lung] present in test data point [True]
# 422 Text feature [decrease] present in test data point [True]
# 430 Text feature [prognosis] present in test data point [True]
# 432 Text feature [sirna] present in test data point [True]
# 436 Text feature [mechanisms] present in test data point [True]
# 438 Text feature [contained] present in test data point [True]
# 446 Text feature [s3] present in test data point [True]
# 451 Text feature [open] present in test data point [True]
# 452 Text feature [position] present in test data point [True]
# 462 Text feature [increase] present in test data point [True]
# 465 Text feature [equivalent] present in test data point [True]
# 466 Text feature [index] present in test data point [True]
# 468 Text feature [stat3] present in test data point [True]
# 469 Text feature [note] present in test data point [True]
# 470 Text feature [14] present in test data point [True]
# 471 Text feature [size] present in test data point [True]
# 477 Text feature [her2] present in test data point [True]
# 478 Text feature [designed] present in test data point [True]
# 480 Text feature [sensitive] present in test data point [True]
# 484 Text feature [separated] present in test data point [True]
# 486 Text feature [deletion] present in test data point [True]
# 489 Text feature [inhibitor] present in test data point [True]
# 491 Text feature [driven] present in test data point [True]
# 497 Text feature [transient] present in test data point [True]
# 498 Text feature [current] present in test data point [True]
# Out of the top  500  features  113 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.0441 0.0555 0.0164 0.114  0.0495 0.0092 0.0679 0.0148 0.6287]]
# Actual Class : 9
# --------------------------------------------------
# 14 Text feature [alternative] present in test data point [True]
# 17 Text feature [splice] present in test data point [True]
# 18 Text feature [ezh2] present in test data point [True]
# 21 Text feature [sf3b1] present in test data point [True]
# 24 Text feature [histone] present in test data point [True]
# 26 Text feature [sequences] present in test data point [True]
# 29 Text feature [splicing] present in test data point [True]
# 32 Text feature [methylation] present in test data point [True]
# 35 Text feature [mds] present in test data point [True]
# 36 Text feature [rather] present in test data point [True]
# 38 Text feature [specific] present in test data point [True]
# 39 Text feature [rna] present in test data point [True]
# 42 Text feature [target] present in test data point [True]
# 46 Text feature [differential] present in test data point [True]
# 52 Text feature [schematic] present in test data point [True]
# 53 Text feature [alter] present in test data point [True]
# 55 Text feature [generate] present in test data point [True]
# 56 Text feature [sites] present in test data point [True]
# 59 Text feature [pre] present in test data point [True]
# 63 Text feature [linked] present in test data point [True]
# 65 Text feature [harboring] present in test data point [True]
# 66 Text feature [mutant] present in test data point [True]
# 71 Text feature [consequences] present in test data point [True]
# 72 Text feature [seq] present in test data point [True]
# 73 Text feature [positions] present in test data point [True]
# 75 Text feature [purchased] present in test data point [True]
# 77 Text feature [complete] present in test data point [True]
# 78 Text feature [wt] present in test data point [True]
# 81 Text feature [harvested] present in test data point [True]
# 82 Text feature [exons] present in test data point [True]
# 85 Text feature [followed] present in test data point [True]
# 86 Text feature [efficiency] present in test data point [True]
# 89 Text feature [targets] present in test data point [True]
# 91 Text feature [locus] present in test data point [True]
# 93 Text feature [samples] present in test data point [True]
# 94 Text feature [selective] present in test data point [True]
# 95 Text feature [allowed] present in test data point [True]
# 96 Text feature [findings] present in test data point [True]
# 100 Text feature [represent] present in test data point [True]
# 102 Text feature [altered] present in test data point [True]
# 106 Text feature [critical] present in test data point [True]
# 107 Text feature [standard] present in test data point [True]
# 109 Text feature [sample] present in test data point [True]
# 121 Text feature [determined] present in test data point [True]
# 125 Text feature [dependent] present in test data point [True]
# 128 Text feature [isolated] present in test data point [True]
# 129 Text feature [ratio] present in test data point [True]
# 130 Text feature [promoter] present in test data point [True]
# 131 Text feature [unknown] present in test data point [True]
# 132 Text feature [error] present in test data point [True]
# 139 Text feature [exhibit] present in test data point [True]
# 150 Text feature [vector] present in test data point [True]
# 159 Text feature [occur] present in test data point [True]
# 162 Text feature [procedures] present in test data point [True]
# 163 Text feature [events] present in test data point [True]
# 164 Text feature [pattern] present in test data point [True]
# 165 Text feature [subjected] present in test data point [True]
# 167 Text feature [states] present in test data point [True]
# 169 Text feature [bearing] present in test data point [True]
# 170 Text feature [together] present in test data point [True]
# 172 Text feature [numbers] present in test data point [True]
# 178 Text feature [base] present in test data point [True]
# 179 Text feature [core] present in test data point [True]
# 180 Text feature [pbs] present in test data point [True]
# 183 Text feature [parental] present in test data point [True]
# 184 Text feature [synthesis] present in test data point [True]
# 189 Text feature [normalized] present in test data point [True]
# 191 Text feature [site] present in test data point [True]
# 194 Text feature [200] present in test data point [True]
# 195 Text feature [heterozygous] present in test data point [True]
# 199 Text feature [reverse] present in test data point [True]
# 201 Text feature [heat] present in test data point [True]
# 207 Text feature [cloned] present in test data point [True]
# 208 Text feature [mouse] present in test data point [True]
# 209 Text feature [status] present in test data point [True]
# 213 Text feature [quantitative] present in test data point [True]
# 215 Text feature [loss] present in test data point [True]
# 219 Text feature [strategy] present in test data point [True]
# 223 Text feature [knockdown] present in test data point [True]
# 225 Text feature [initial] present in test data point [True]
# 232 Text feature [within] present in test data point [True]
# 234 Text feature [reduction] present in test data point [True]
# 241 Text feature [containing] present in test data point [True]
# 243 Text feature [intron] present in test data point [True]
# 244 Text feature [lymphoma] present in test data point [True]
# 248 Text feature [index] present in test data point [True]
# 254 Text feature [obtained] present in test data point [True]
# 256 Text feature [substrate] present in test data point [True]
# 258 Text feature [third] present in test data point [True]
# 261 Text feature [database] present in test data point [True]
# 266 Text feature [rt] present in test data point [True]
# 267 Text feature [explain] present in test data point [True]
# 276 Text feature [endogenous] present in test data point [True]
# 278 Text feature [inhibited] present in test data point [True]
# 281 Text feature [confirm] present in test data point [True]
# 282 Text feature [component] present in test data point [True]
# 283 Text feature [expressing] present in test data point [True]
# 286 Text feature [materials] present in test data point [True]
# 288 Text feature [reads] present in test data point [True]
# 289 Text feature [set] present in test data point [True]
# 290 Text feature [similarly] present in test data point [True]
# 291 Text feature [version] present in test data point [True]
# 292 Text feature [culture] present in test data point [True]
# 294 Text feature [human] present in test data point [True]
# 295 Text feature [sensitive] present in test data point [True]
# 296 Text feature [conducted] present in test data point [True]
# 297 Text feature [levels] present in test data point [True]
# 298 Text feature [secondary] present in test data point [True]
# 301 Text feature [11] present in test data point [True]
# 312 Text feature [000] present in test data point [True]
# 313 Text feature [induction] present in test data point [True]
# 318 Text feature [clone] present in test data point [True]
# 323 Text feature [impact] present in test data point [True]
# 325 Text feature [series] present in test data point [True]
# 327 Text feature [note] present in test data point [True]
# 329 Text feature [biotechnology] present in test data point [True]
# 331 Text feature [direct] present in test data point [True]
# 332 Text feature [ii] present in test data point [True]
# 335 Text feature [using] present in test data point [True]
# 336 Text feature [array] present in test data point [True]
# 337 Text feature [concentration] present in test data point [True]
# 342 Text feature [transcription] present in test data point [True]
# 343 Text feature [compared] present in test data point [True]
# 346 Text feature [every] present in test data point [True]
# 350 Text feature [tolerated] present in test data point [True]
# 353 Text feature [codons] present in test data point [True]
# 354 Text feature [3d] present in test data point [True]
# 355 Text feature [5a] present in test data point [True]
# 358 Text feature [normal] present in test data point [True]
# 359 Text feature [dd] present in test data point [True]
# 363 Text feature [limited] present in test data point [True]
# 366 Text feature [modified] present in test data point [True]
# 375 Text feature [gain] present in test data point [True]
# 377 Text feature [occurs] present in test data point [True]
# 379 Text feature [size] present in test data point [True]
# 383 Text feature [different] present in test data point [True]
# 385 Text feature [allow] present in test data point [True]
# 387 Text feature [suggests] present in test data point [True]
# 393 Text feature [result] present in test data point [True]
# 394 Text feature [expressed] present in test data point [True]
# 396 Text feature [confirmed] present in test data point [True]
# 399 Text feature [depletion] present in test data point [True]
# 405 Text feature [resulted] present in test data point [True]
# 407 Text feature [generated] present in test data point [True]
# 411 Text feature [subunit] present in test data point [True]
# 412 Text feature [clones] present in test data point [True]
# 415 Text feature [suggest] present in test data point [True]
# 420 Text feature [extent] present in test data point [True]
# 421 Text feature [phenotype] present in test data point [True]
# 422 Text feature [system] present in test data point [True]
# 426 Text feature [embryonic] present in test data point [True]
# 428 Text feature [cellular] present in test data point [True]
# Out of the top  500  features  152 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1725143867012888
# for alpha = 1e-05
# Log Loss : 1.1535904520949654
# for alpha = 0.0001
# Log Loss : 1.0564858637340613
# for alpha = 0.001
# Log Loss : 1.1309296728342115
# for alpha = 0.01
# Log Loss : 1.472576522972783
# for alpha = 0.1
# Log Loss : 1.8019484386240707
# for alpha = 1
# Log Loss : 1.8974715296104168
# For values of best alpha =  0.0001 The train log loss is: 0.45397410043053743
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0564858637340613
# For values of best alpha =  0.0001 The test log loss is: 0.9627726705559013

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0564858637340613
# Number of mis-classified points : 0.34962406015037595
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[1.210e-02 2.660e-02 2.710e-02 1.200e-02 2.090e-02 5.400e-03 8.938e-01
#   1.600e-03 4.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [intrinsic] present in test data point [True]
# 32 Text feature [thyroid] present in test data point [True]
# 47 Text feature [insertion] present in test data point [True]
# 49 Text feature [downstream] present in test data point [True]
# 56 Text feature [oncogene] present in test data point [True]
# 60 Text feature [increases] present in test data point [True]
# 66 Text feature [tk] present in test data point [True]
# 73 Text feature [activated] present in test data point [True]
# 74 Text feature [protocol] present in test data point [True]
# 75 Text feature [transformed] present in test data point [True]
# 90 Text feature [overexpression] present in test data point [True]
# 92 Text feature [concentrations] present in test data point [True]
# 96 Text feature [murine] present in test data point [True]
# 107 Text feature [extracellular] present in test data point [True]
# 111 Text feature [segment] present in test data point [True]
# 114 Text feature [cross] present in test data point [True]
# 115 Text feature [immunoblot] present in test data point [True]
# 118 Text feature [constitutive] present in test data point [True]
# 120 Text feature [factor] present in test data point [True]
# 131 Text feature [activation] present in test data point [True]
# 135 Text feature [akt] present in test data point [True]
# 143 Text feature [heterogeneity] present in test data point [True]
# 150 Text feature [untreated] present in test data point [True]
# 166 Text feature [ligands] present in test data point [True]
# 173 Text feature [oncogenes] present in test data point [True]
# 175 Text feature [bp] present in test data point [True]
# 179 Text feature [extent] present in test data point [True]
# 181 Text feature [oncogenic] present in test data point [True]
# 182 Text feature [minutes] present in test data point [True]
# 185 Text feature [ligand] present in test data point [True]
# 208 Text feature [lesions] present in test data point [True]
# 221 Text feature [inhibited] present in test data point [True]
# 231 Text feature [coding] present in test data point [True]
# 232 Text feature [phospho] present in test data point [True]
# 233 Text feature [induces] present in test data point [True]
# 236 Text feature [fragment] present in test data point [True]
# 243 Text feature [enhanced] present in test data point [True]
# 244 Text feature [lipid] present in test data point [True]
# 249 Text feature [phosphorylated] present in test data point [True]
# 252 Text feature [adenocarcinoma] present in test data point [True]
# 254 Text feature [prognostic] present in test data point [True]
# 267 Text feature [moreover] present in test data point [True]
# 277 Text feature [signaling] present in test data point [True]
# 283 Text feature [transforming] present in test data point [True]
# 299 Text feature [regulated] present in test data point [True]
# 304 Text feature [catenin] present in test data point [True]
# 305 Text feature [approximately] present in test data point [True]
# 313 Text feature [injected] present in test data point [True]
# 315 Text feature [metastasis] present in test data point [True]
# 316 Text feature [acute] present in test data point [True]
# 317 Text feature [increased] present in test data point [True]
# 319 Text feature [distinct] present in test data point [True]
# 324 Text feature [approved] present in test data point [True]
# 325 Text feature [phosphorylation] present in test data point [True]
# 326 Text feature [pathways] present in test data point [True]
# 330 Text feature [3t3] present in test data point [True]
# 337 Text feature [homology] present in test data point [True]
# 338 Text feature [expressing] present in test data point [True]
# 346 Text feature [means] present in test data point [True]
# 350 Text feature [codons] present in test data point [True]
# 352 Text feature [note] present in test data point [True]
# 354 Text feature [3b] present in test data point [True]
# 356 Text feature [clearly] present in test data point [True]
# 357 Text feature [display] present in test data point [True]
# 363 Text feature [inhibits] present in test data point [True]
# 369 Text feature [gfp] present in test data point [True]
# 370 Text feature [promoting] present in test data point [True]
# 371 Text feature [500] present in test data point [True]
# 383 Text feature [ras] present in test data point [True]
# 384 Text feature [epithelial] present in test data point [True]
# 386 Text feature [index] present in test data point [True]
# 388 Text feature [leading] present in test data point [True]
# 391 Text feature [serine] present in test data point [True]
# 395 Text feature [bone] present in test data point [True]
# 396 Text feature [equivalent] present in test data point [True]
# 397 Text feature [itd] present in test data point [True]
# 399 Text feature [alteration] present in test data point [True]
# 404 Text feature [s3] present in test data point [True]
# 406 Text feature [de] present in test data point [True]
# 408 Text feature [signals] present in test data point [True]
# 411 Text feature [14] present in test data point [True]
# 412 Text feature [transformation] present in test data point [True]
# 419 Text feature [receptors] present in test data point [True]
# 424 Text feature [activate] present in test data point [True]
# 428 Text feature [decrease] present in test data point [True]
# 429 Text feature [designed] present in test data point [True]
# 432 Text feature [produced] present in test data point [True]
# 444 Text feature [hematopoietic] present in test data point [True]
# 447 Text feature [presence] present in test data point [True]
# 448 Text feature [egfr] present in test data point [True]
# 452 Text feature [marrow] present in test data point [True]
# 453 Text feature [colonies] present in test data point [True]
# 459 Text feature [signalling] present in test data point [True]
# 462 Text feature [account] present in test data point [True]
# 464 Text feature [promotes] present in test data point [True]
# 465 Text feature [position] present in test data point [True]
# 468 Text feature [event] present in test data point [True]
# 473 Text feature [sirna] present in test data point [True]
# 474 Text feature [express] present in test data point [True]
# 480 Text feature [stably] present in test data point [True]
# 481 Text feature [codon] present in test data point [True]
# 482 Text feature [prognosis] present in test data point [True]
# 484 Text feature [positive] present in test data point [True]
# 486 Text feature [her2] present in test data point [True]
# 493 Text feature [deletion] present in test data point [True]
# 496 Text feature [leukemia] present in test data point [True]
# 497 Text feature [molecule] present in test data point [True]
# 499 Text feature [effectors] present in test data point [True]
# Out of the top  500  features  108 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.0294 0.0395 0.0077 0.092  0.0345 0.0057 0.0436 0.0065 0.7411]]
# Actual Class : 9
# --------------------------------------------------
# 12 Text feature [sf3b1] present in test data point [True]
# 14 Text feature [ezh2] present in test data point [True]
# 25 Text feature [splicing] present in test data point [True]
# 26 Text feature [differential] present in test data point [True]
# 27 Text feature [methylation] present in test data point [True]
# 28 Text feature [splice] present in test data point [True]
# 29 Text feature [alternative] present in test data point [True]
# 34 Text feature [histone] present in test data point [True]
# 35 Text feature [mds] present in test data point [True]
# 39 Text feature [rna] present in test data point [True]
# 42 Text feature [aberrant] present in test data point [True]
# 43 Text feature [sites] present in test data point [True]
# 51 Text feature [pre] present in test data point [True]
# 54 Text feature [seq] present in test data point [True]
# 58 Text feature [specific] present in test data point [True]
# 60 Text feature [sequences] present in test data point [True]
# 63 Text feature [alter] present in test data point [True]
# 66 Text feature [rather] present in test data point [True]
# 77 Text feature [purchased] present in test data point [True]
# 83 Text feature [harvested] present in test data point [True]
# 84 Text feature [positions] present in test data point [True]
# 87 Text feature [linked] present in test data point [True]
# 88 Text feature [consequences] present in test data point [True]
# 91 Text feature [target] present in test data point [True]
# 92 Text feature [exons] present in test data point [True]
# 94 Text feature [events] present in test data point [True]
# 95 Text feature [harboring] present in test data point [True]
# 98 Text feature [locus] present in test data point [True]
# 100 Text feature [samples] present in test data point [True]
# 101 Text feature [selective] present in test data point [True]
# 105 Text feature [complete] present in test data point [True]
# 107 Text feature [altered] present in test data point [True]
# 108 Text feature [mutant] present in test data point [True]
# 110 Text feature [depletion] present in test data point [True]
# 111 Text feature [pbs] present in test data point [True]
# 112 Text feature [normalized] present in test data point [True]
# 113 Text feature [targets] present in test data point [True]
# 115 Text feature [akt] present in test data point [True]
# 116 Text feature [wt] present in test data point [True]
# 117 Text feature [efficiency] present in test data point [True]
# 118 Text feature [reads] present in test data point [True]
# 121 Text feature [generate] present in test data point [True]
# 123 Text feature [sample] present in test data point [True]
# 127 Text feature [intron] present in test data point [True]
# 128 Text feature [knockdown] present in test data point [True]
# 129 Text feature [followed] present in test data point [True]
# 137 Text feature [exhibit] present in test data point [True]
# 138 Text feature [schematic] present in test data point [True]
# 139 Text feature [lymphoma] present in test data point [True]
# 141 Text feature [critical] present in test data point [True]
# 145 Text feature [dd] present in test data point [True]
# 148 Text feature [allowed] present in test data point [True]
# 152 Text feature [occurs] present in test data point [True]
# 157 Text feature [clone] present in test data point [True]
# 159 Text feature [findings] present in test data point [True]
# 163 Text feature [core] present in test data point [True]
# 164 Text feature [array] present in test data point [True]
# 165 Text feature [parental] present in test data point [True]
# 168 Text feature [standard] present in test data point [True]
# 171 Text feature [promoter] present in test data point [True]
# 175 Text feature [substrate] present in test data point [True]
# 176 Text feature [isolated] present in test data point [True]
# 180 Text feature [set] present in test data point [True]
# 182 Text feature [3d] present in test data point [True]
# 185 Text feature [heterozygous] present in test data point [True]
# 189 Text feature [endogenous] present in test data point [True]
# 192 Text feature [200] present in test data point [True]
# 196 Text feature [procedures] present in test data point [True]
# 198 Text feature [loss] present in test data point [True]
# 209 Text feature [subjected] present in test data point [True]
# 210 Text feature [extent] present in test data point [True]
# 211 Text feature [human] present in test data point [True]
# 212 Text feature [induction] present in test data point [True]
# 215 Text feature [reduction] present in test data point [True]
# 219 Text feature [patterns] present in test data point [True]
# 226 Text feature [media] present in test data point [True]
# 228 Text feature [represent] present in test data point [True]
# 232 Text feature [bearing] present in test data point [True]
# 236 Text feature [density] present in test data point [True]
# 243 Text feature [culture] present in test data point [True]
# 244 Text feature [site] present in test data point [True]
# 250 Text feature [tagged] present in test data point [True]
# 254 Text feature [limited] present in test data point [True]
# 255 Text feature [technologies] present in test data point [True]
# 258 Text feature [reverse] present in test data point [True]
# 260 Text feature [mouse] present in test data point [True]
# 297 Text feature [component] present in test data point [True]
# 475 Text feature [numbers] present in test data point [True]
# Out of the top  500  features  88 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1059148899867153
# for C = 0.0001
# Log Loss : 1.075845274906382
# for C = 0.001
# Log Loss : 1.072265634294063
# for C = 0.01
# Log Loss : 1.239045333103524
# for C = 0.1
# Log Loss : 1.7775834104241117
# for C = 1
# Log Loss : 1.8889949701325115
# for C = 10
# Log Loss : 1.888995089067678
# for C = 100
# Log Loss : 1.8889952438781055
# For values of best alpha =  0.001 The train log loss is: 0.5990004203015363
# For values of best alpha =  0.001 The cross validation log loss is: 1.072265634294063
# For values of best alpha =  0.001 The test log loss is: 0.9960662599698524

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.072265634294063
# Number of mis-classified points : 0.35526315789473684
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0507 0.0574 0.0439 0.0565 0.0299 0.0149 0.7419 0.0031 0.0017]]
# Actual Class : 7
# --------------------------------------------------
# 22 Text feature [intrinsic] present in test data point [True]
# 30 Text feature [concentrations] present in test data point [True]
# 31 Text feature [insertion] present in test data point [True]
# 32 Text feature [constitutive] present in test data point [True]
# 33 Text feature [tk] present in test data point [True]
# 34 Text feature [akt] present in test data point [True]
# 35 Text feature [extracellular] present in test data point [True]
# 37 Text feature [downstream] present in test data point [True]
# 38 Text feature [immunoblot] present in test data point [True]
# 40 Text feature [murine] present in test data point [True]
# 41 Text feature [protocol] present in test data point [True]
# 42 Text feature [oncogene] present in test data point [True]
# 55 Text feature [factor] present in test data point [True]
# 56 Text feature [thyroid] present in test data point [True]
# 59 Text feature [ligand] present in test data point [True]
# 61 Text feature [inhibited] present in test data point [True]
# 65 Text feature [segment] present in test data point [True]
# 67 Text feature [transformed] present in test data point [True]
# 68 Text feature [activation] present in test data point [True]
# 69 Text feature [enhanced] present in test data point [True]
# 72 Text feature [oncogenic] present in test data point [True]
# 74 Text feature [increases] present in test data point [True]
# 78 Text feature [activated] present in test data point [True]
# 193 Text feature [expressing] present in test data point [True]
# 195 Text feature [approved] present in test data point [True]
# 196 Text feature [extent] present in test data point [True]
# 197 Text feature [gfp] present in test data point [True]
# 198 Text feature [heterogeneity] present in test data point [True]
# 200 Text feature [homology] present in test data point [True]
# 201 Text feature [signaling] present in test data point [True]
# 202 Text feature [lipid] present in test data point [True]
# 205 Text feature [injected] present in test data point [True]
# 206 Text feature [bp] present in test data point [True]
# 207 Text feature [oncogenes] present in test data point [True]
# 208 Text feature [phosphorylated] present in test data point [True]
# 209 Text feature [promoting] present in test data point [True]
# 211 Text feature [ligands] present in test data point [True]
# 212 Text feature [event] present in test data point [True]
# 213 Text feature [cross] present in test data point [True]
# 214 Text feature [approximately] present in test data point [True]
# 216 Text feature [3b] present in test data point [True]
# 217 Text feature [marrow] present in test data point [True]
# 221 Text feature [pathways] present in test data point [True]
# 222 Text feature [minutes] present in test data point [True]
# 224 Text feature [fragment] present in test data point [True]
# 227 Text feature [sensitive] present in test data point [True]
# 228 Text feature [catenin] present in test data point [True]
# 229 Text feature [lesions] present in test data point [True]
# 230 Text feature [transforming] present in test data point [True]
# 231 Text feature [signals] present in test data point [True]
# 349 Text feature [means] present in test data point [True]
# 350 Text feature [bone] present in test data point [True]
# 351 Text feature [moreover] present in test data point [True]
# 353 Text feature [overexpression] present in test data point [True]
# 354 Text feature [alteration] present in test data point [True]
# 355 Text feature [codon] present in test data point [True]
# 356 Text feature [equivalent] present in test data point [True]
# 357 Text feature [coding] present in test data point [True]
# 358 Text feature [leukemia] present in test data point [True]
# 363 Text feature [increased] present in test data point [True]
# 364 Text feature [reviewed] present in test data point [True]
# 365 Text feature [adenocarcinoma] present in test data point [True]
# 366 Text feature [untreated] present in test data point [True]
# 368 Text feature [hematopoietic] present in test data point [True]
# 369 Text feature [though] present in test data point [True]
# 371 Text feature [decrease] present in test data point [True]
# 372 Text feature [acute] present in test data point [True]
# 373 Text feature [stably] present in test data point [True]
# 376 Text feature [mutants] present in test data point [True]
# 377 Text feature [phosphorylation] present in test data point [True]
# 378 Text feature [egfr] present in test data point [True]
# 380 Text feature [activate] present in test data point [True]
# 382 Text feature [clearly] present in test data point [True]
# 383 Text feature [exhibited] present in test data point [True]
# 385 Text feature [derived] present in test data point [True]
# 386 Text feature [induces] present in test data point [True]
# 387 Text feature [examined] present in test data point [True]
# 389 Text feature [colonies] present in test data point [True]
# 390 Text feature [3t3] present in test data point [True]
# 391 Text feature [seeded] present in test data point [True]
# 392 Text feature [colony] present in test data point [True]
# 397 Text feature [induction] present in test data point [True]
# 398 Text feature [index] present in test data point [True]
# 399 Text feature [bands] present in test data point [True]
# 400 Text feature [14] present in test data point [True]
# 402 Text feature [caused] present in test data point [True]
# 403 Text feature [codons] present in test data point [True]
# 404 Text feature [prognostic] present in test data point [True]
# 405 Text feature [activating] present in test data point [True]
# 406 Text feature [inhibits] present in test data point [True]
# 407 Text feature [near] present in test data point [True]
# 408 Text feature [s3] present in test data point [True]
# 409 Text feature [account] present in test data point [True]
# 410 Text feature [note] present in test data point [True]
# 411 Text feature [strongly] present in test data point [True]
# 412 Text feature [wt] present in test data point [True]
# 413 Text feature [her2] present in test data point [True]
# 414 Text feature [increase] present in test data point [True]
# 415 Text feature [regulated] present in test data point [True]
# 417 Text feature [involving] present in test data point [True]
# 418 Text feature [inhibitor] present in test data point [True]
# 419 Text feature [driven] present in test data point [True]
# 420 Text feature [000] present in test data point [True]
# 428 Text feature [position] present in test data point [True]
# 429 Text feature [concentration] present in test data point [True]
# 430 Text feature [ba] present in test data point [True]
# 433 Text feature [ras] present in test data point [True]
# 434 Text feature [molecule] present in test data point [True]
# 442 Text feature [immunohistochemistry] present in test data point [True]
# 443 Text feature [open] present in test data point [True]
# 444 Text feature [egf] present in test data point [True]
# 445 Text feature [2c] present in test data point [True]
# Out of the top  500  features  112 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.0499 0.0416 0.011  0.0999 0.0458 0.0062 0.0773 0.0042 0.6643]]
# Actual Class : 9
# --------------------------------------------------
# 14 Text feature [sf3b1] present in test data point [True]
# 15 Text feature [ezh2] present in test data point [True]
# 19 Text feature [splicing] present in test data point [True]
# 24 Text feature [differential] present in test data point [True]
# 25 Text feature [splice] present in test data point [True]
# 26 Text feature [mds] present in test data point [True]
# 27 Text feature [alternative] present in test data point [True]
# 29 Text feature [histone] present in test data point [True]
# 37 Text feature [rna] present in test data point [True]
# 39 Text feature [seq] present in test data point [True]
# 40 Text feature [pre] present in test data point [True]
# 45 Text feature [sites] present in test data point [True]
# 47 Text feature [events] present in test data point [True]
# 49 Text feature [alter] present in test data point [True]
# 52 Text feature [aberrant] present in test data point [True]
# 53 Text feature [mutant] present in test data point [True]
# 57 Text feature [targets] present in test data point [True]
# 64 Text feature [exons] present in test data point [True]
# 65 Text feature [sequences] present in test data point [True]
# 68 Text feature [generate] present in test data point [True]
# 69 Text feature [methylation] present in test data point [True]
# 73 Text feature [sample] present in test data point [True]
# 76 Text feature [specific] present in test data point [True]
# 79 Text feature [wt] present in test data point [True]
# 82 Text feature [positions] present in test data point [True]
# 83 Text feature [efficiency] present in test data point [True]
# 84 Text feature [depletion] present in test data point [True]
# 85 Text feature [consequences] present in test data point [True]
# 87 Text feature [substrate] present in test data point [True]
# 89 Text feature [reads] present in test data point [True]
# 90 Text feature [harboring] present in test data point [True]
# 91 Text feature [knockdown] present in test data point [True]
# 93 Text feature [selective] present in test data point [True]
# 95 Text feature [samples] present in test data point [True]
# 97 Text feature [harvested] present in test data point [True]
# 98 Text feature [schematic] present in test data point [True]
# 99 Text feature [followed] present in test data point [True]
# 100 Text feature [dd] present in test data point [True]
# 101 Text feature [target] present in test data point [True]
# 102 Text feature [rather] present in test data point [True]
# 105 Text feature [normalized] present in test data point [True]
# 108 Text feature [critical] present in test data point [True]
# 112 Text feature [extent] present in test data point [True]
# 115 Text feature [procedures] present in test data point [True]
# 117 Text feature [set] present in test data point [True]
# 118 Text feature [purchased] present in test data point [True]
# 119 Text feature [intron] present in test data point [True]
# 120 Text feature [array] present in test data point [True]
# 121 Text feature [core] present in test data point [True]
# 123 Text feature [locus] present in test data point [True]
# 125 Text feature [endogenous] present in test data point [True]
# 127 Text feature [occurs] present in test data point [True]
# 132 Text feature [lymphoma] present in test data point [True]
# 135 Text feature [limited] present in test data point [True]
# 137 Text feature [altered] present in test data point [True]
# 138 Text feature [allowed] present in test data point [True]
# 139 Text feature [complete] present in test data point [True]
# 142 Text feature [ring] present in test data point [True]
# 147 Text feature [heterozygous] present in test data point [True]
# 148 Text feature [occur] present in test data point [True]
# 149 Text feature [findings] present in test data point [True]
# 151 Text feature [exhibit] present in test data point [True]
# 164 Text feature [bearing] present in test data point [True]
# 166 Text feature [different] present in test data point [True]
# 168 Text feature [culture] present in test data point [True]
# 171 Text feature [linked] present in test data point [True]
# 172 Text feature [pbs] present in test data point [True]
# 173 Text feature [standard] present in test data point [True]
# 177 Text feature [3d] present in test data point [True]
# 178 Text feature [parental] present in test data point [True]
# 179 Text feature [clone] present in test data point [True]
# 180 Text feature [dependent] present in test data point [True]
# 183 Text feature [modified] present in test data point [True]
# 184 Text feature [subjected] present in test data point [True]
# 185 Text feature [required] present in test data point [True]
# 187 Text feature [error] present in test data point [True]
# 188 Text feature [states] present in test data point [True]
# 189 Text feature [reduction] present in test data point [True]
# 191 Text feature [statistically] present in test data point [True]
# 192 Text feature [sufficient] present in test data point [True]
# 196 Text feature [mrna] present in test data point [True]
# 197 Text feature [200] present in test data point [True]
# 198 Text feature [levels] present in test data point [True]
# 206 Text feature [biological] present in test data point [True]
# 207 Text feature [materials] present in test data point [True]
# 210 Text feature [expressed] present in test data point [True]
# 211 Text feature [tagged] present in test data point [True]
# 213 Text feature [000] present in test data point [True]
# 214 Text feature [targeting] present in test data point [True]
# 215 Text feature [promoter] present in test data point [True]
# 220 Text feature [confirm] present in test data point [True]
# 226 Text feature [isolated] present in test data point [True]
# 228 Text feature [factor] present in test data point [True]
# 229 Text feature [institute] present in test data point [True]
# 230 Text feature [wild] present in test data point [True]
# 232 Text feature [heat] present in test data point [True]
# 236 Text feature [induction] present in test data point [True]
# 237 Text feature [impact] present in test data point [True]
# 240 Text feature [center] present in test data point [True]
# 245 Text feature [site] present in test data point [True]
# 248 Text feature [abnormalities] present in test data point [True]
# 249 Text feature [damage] present in test data point [True]
# 253 Text feature [applied] present in test data point [True]
# 254 Text feature [ratio] present in test data point [True]
# 258 Text feature [pancreatic] present in test data point [True]
# 261 Text feature [5a] present in test data point [True]
# 263 Text feature [component] present in test data point [True]
# 266 Text feature [chronic] present in test data point [True]
# 268 Text feature [resulting] present in test data point [True]
# 271 Text feature [frequencies] present in test data point [True]
# 272 Text feature [process] present in test data point [True]
# 273 Text feature [series] present in test data point [True]
# 274 Text feature [represent] present in test data point [True]
# 275 Text feature [malignancies] present in test data point [True]
# 279 Text feature [added] present in test data point [True]
# 281 Text feature [3c] present in test data point [True]
# 284 Text feature [secondary] present in test data point [True]
# 289 Text feature [third] present in test data point [True]
# 291 Text feature [sigma] present in test data point [True]
# 292 Text feature [within] present in test data point [True]
# 293 Text feature [using] present in test data point [True]
# 294 Text feature [toward] present in test data point [True]
# 296 Text feature [size] present in test data point [True]
# 297 Text feature [loss] present in test data point [True]
# 298 Text feature [akt] present in test data point [True]
# 299 Text feature [30] present in test data point [True]
# 302 Text feature [containing] present in test data point [True]
# 307 Text feature [system] present in test data point [True]
# 311 Text feature [mouse] present in test data point [True]
# 312 Text feature [100] present in test data point [True]
# 313 Text feature [5b] present in test data point [True]
# 315 Text feature [better] present in test data point [True]
# 316 Text feature [technologies] present in test data point [True]
# 318 Text feature [play] present in test data point [True]
# 328 Text feature [reverse] present in test data point [True]
# 329 Text feature [cellular] present in test data point [True]
# 330 Text feature [density] present in test data point [True]
# 332 Text feature [result] present in test data point [True]
# 333 Text feature [cloned] present in test data point [True]
# 338 Text feature [significant] present in test data point [True]
# 343 Text feature [initial] present in test data point [True]
# 344 Text feature [clones] present in test data point [True]
# 346 Text feature [generation] present in test data point [True]
# 352 Text feature [status] present in test data point [True]
# 353 Text feature [similarly] present in test data point [True]
# 356 Text feature [75] present in test data point [True]
# 360 Text feature [test] present in test data point [True]
# 363 Text feature [primary] present in test data point [True]
# 369 Text feature [type] present in test data point [True]
# 370 Text feature [strongly] present in test data point [True]
# 371 Text feature [provided] present in test data point [True]
# 374 Text feature [genes] present in test data point [True]
# 378 Text feature [genome] present in test data point [True]
# 380 Text feature [ability] present in test data point [True]
# 381 Text feature [observed] present in test data point [True]
# 386 Text feature [direct] present in test data point [True]
# 387 Text feature [bottom] present in test data point [True]
# 392 Text feature [human] present in test data point [True]
# 393 Text feature [models] present in test data point [True]
# 394 Text feature [research] present in test data point [True]
# 395 Text feature [figs] present in test data point [True]
# 397 Text feature [database] present in test data point [True]
# 402 Text feature [gain] present in test data point [True]
# 403 Text feature [fact] present in test data point [True]
# 405 Text feature [recombination] present in test data point [True]
# 409 Text feature [kb] present in test data point [True]
# 410 Text feature [expected] present in test data point [True]
# 411 Text feature [strategy] present in test data point [True]
# 413 Text feature [homology] present in test data point [True]
# 414 Text feature [resulted] present in test data point [True]
# 415 Text feature [vector] present in test data point [True]
# 416 Text feature [compounds] present in test data point [True]
# 417 Text feature [tolerated] present in test data point [True]
# 419 Text feature [pattern] present in test data point [True]
# 420 Text feature [determined] present in test data point [True]
# 421 Text feature [concentration] present in test data point [True]
# 423 Text feature [impaired] present in test data point [True]
# 425 Text feature [prognosis] present in test data point [True]
# 436 Text feature [media] present in test data point [True]
# Out of the top  500  features  179 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2061474809816946
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.208588146221614
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2028174291487777
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1994506454125882
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.198265297278281
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.1986447452682438
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1945932238325698
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1954213450081892
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1918205475652495
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.194569087119598
# For values of best estimator =  2000 The train log loss is: 0.8752199520172443
# For values of best estimator =  2000 The cross validation log loss is: 1.1918205475652495
# For values of best estimator =  2000 The test log loss is: 1.1356666913971392

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1918205475652495
# Number of mis-classified points : 0.4323308270676692
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[8.100e-03 8.670e-02 2.270e-02 9.100e-03 2.890e-02 2.340e-02 8.169e-01
#   3.700e-03 4.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 5 Text feature [activated] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 8 Text feature [inhibitors] present in test data point [True]
# 9 Text feature [tyrosine] present in test data point [True]
# 11 Text feature [suppressor] present in test data point [True]
# 12 Text feature [treatment] present in test data point [True]
# 13 Text feature [constitutive] present in test data point [True]
# 14 Text feature [function] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 18 Text feature [inhibitor] present in test data point [True]
# 19 Text feature [nonsense] present in test data point [True]
# 20 Text feature [therapy] present in test data point [True]
# 21 Text feature [missense] present in test data point [True]
# 22 Text feature [oncogenic] present in test data point [True]
# 23 Text feature [erk] present in test data point [True]
# 25 Text feature [signaling] present in test data point [True]
# 26 Text feature [receptor] present in test data point [True]
# 28 Text feature [constitutively] present in test data point [True]
# 31 Text feature [treated] present in test data point [True]
# 32 Text feature [transforming] present in test data point [True]
# 33 Text feature [pathogenic] present in test data point [True]
# 35 Text feature [trials] present in test data point [True]
# 36 Text feature [akt] present in test data point [True]
# 38 Text feature [growth] present in test data point [True]
# 39 Text feature [deleterious] present in test data point [True]
# 41 Text feature [stability] present in test data point [True]
# 42 Text feature [cells] present in test data point [True]
# 44 Text feature [downstream] present in test data point [True]
# 46 Text feature [inhibited] present in test data point [True]
# 47 Text feature [extracellular] present in test data point [True]
# 48 Text feature [repair] present in test data point [True]
# 49 Text feature [therapeutic] present in test data point [True]
# 50 Text feature [expression] present in test data point [True]
# 52 Text feature [protein] present in test data point [True]
# 54 Text feature [functional] present in test data point [True]
# 55 Text feature [proliferation] present in test data point [True]
# 57 Text feature [phosphatase] present in test data point [True]
# 59 Text feature [resistance] present in test data point [True]
# 60 Text feature [neutral] present in test data point [True]
# 61 Text feature [classified] present in test data point [True]
# 63 Text feature [variants] present in test data point [True]
# 64 Text feature [odds] present in test data point [True]
# 65 Text feature [cell] present in test data point [True]
# 67 Text feature [months] present in test data point [True]
# 68 Text feature [response] present in test data point [True]
# 72 Text feature [patients] present in test data point [True]
# 74 Text feature [inhibition] present in test data point [True]
# 77 Text feature [3t3] present in test data point [True]
# 78 Text feature [mek] present in test data point [True]
# 79 Text feature [unclassified] present in test data point [True]
# 81 Text feature [f3] present in test data point [True]
# 83 Text feature [activate] present in test data point [True]
# 88 Text feature [survival] present in test data point [True]
# 89 Text feature [retained] present in test data point [True]
# 94 Text feature [expressing] present in test data point [True]
# 95 Text feature [predicted] present in test data point [True]
# 96 Text feature [drug] present in test data point [True]
# 98 Text feature [defective] present in test data point [True]
# 99 Text feature [kinases] present in test data point [True]
# Out of the top  100  features  62 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.172  0.0724 0.0153 0.167  0.0402 0.0365 0.0992 0.0105 0.387 ]]
# Actuall Class : 9
# --------------------------------------------------
# 5 Text feature [activated] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 8 Text feature [inhibitors] present in test data point [True]
# 11 Text feature [suppressor] present in test data point [True]
# 12 Text feature [treatment] present in test data point [True]
# 13 Text feature [constitutive] present in test data point [True]
# 14 Text feature [function] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 18 Text feature [inhibitor] present in test data point [True]
# 20 Text feature [therapy] present in test data point [True]
# 21 Text feature [missense] present in test data point [True]
# 22 Text feature [oncogenic] present in test data point [True]
# 25 Text feature [signaling] present in test data point [True]
# 31 Text feature [treated] present in test data point [True]
# 35 Text feature [trials] present in test data point [True]
# 36 Text feature [akt] present in test data point [True]
# 38 Text feature [growth] present in test data point [True]
# 41 Text feature [stability] present in test data point [True]
# 42 Text feature [cells] present in test data point [True]
# 44 Text feature [downstream] present in test data point [True]
# 46 Text feature [inhibited] present in test data point [True]
# 49 Text feature [therapeutic] present in test data point [True]
# 50 Text feature [expression] present in test data point [True]
# 52 Text feature [protein] present in test data point [True]
# 54 Text feature [functional] present in test data point [True]
# 55 Text feature [proliferation] present in test data point [True]
# 57 Text feature [phosphatase] present in test data point [True]
# 59 Text feature [resistance] present in test data point [True]
# 61 Text feature [classified] present in test data point [True]
# 63 Text feature [variants] present in test data point [True]
# 65 Text feature [cell] present in test data point [True]
# 68 Text feature [response] present in test data point [True]
# 72 Text feature [patients] present in test data point [True]
# 74 Text feature [inhibition] present in test data point [True]
# 88 Text feature [survival] present in test data point [True]
# 94 Text feature [expressing] present in test data point [True]
# 98 Text feature [defective] present in test data point [True]
# Out of the top  100  features  37 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.1724454670722704
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.7434076715077458
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.5610729433213018
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.8046386615252366
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7220466512291774
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.5162382119815883
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.4737545557595455
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6527370904381575
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5365044522213342
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.5537271401937198
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2935222891799714
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.5554893108895875
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.5886644093169573
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.5505028783831298
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3296079913884828
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.6035059033186703
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.6865344430376157
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5915102073491423
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.3534907874133393
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.6449604455017925
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.6676720149118933
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5960481754582916
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3623882013675406
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.6480515863170098
# For values of best alpha =  100 The train log loss is: 0.055610656191494676
# For values of best alpha =  100 The cross validation log loss is: 1.2935222891799714
# For values of best alpha =  100 The test log loss is: 1.246292389030307

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.2935222891799714
# Number of mis-classified points : 0.5037593984962406
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 3
# Predicted Class Probabilities: [[0.0088 0.0515 0.712  0.0101 0.0133 0.0116 0.18   0.0065 0.0062]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 9
# Predicted Class Probabilities: [[0.047  0.0257 0.0465 0.0366 0.0224 0.0259 0.0124 0.2505 0.533 ]]
# Actual Class : 9
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------

# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------

# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.0001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.000001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Support vector machines : Log Loss: 1.04
# Naive Bayes : Log Loss: 1.22
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.172
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.986
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.376
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.083
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.288
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.675

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.3896253640199306
# Log loss (CV) on the stacking classifier : 1.0832405913969565
# Log loss (test) on the stacking classifier : 1.1574171630232666
# Number of missclassified point : 0.3669172932330827
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 4.7.2 Stacking Models [Logistic , Linear , Random Forest]

# %% [markdown]
# **4.7.2.1 Hyper Paramater Tuning**

# %%
clf1 = SGDClassifier(alpha=0.0001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

clf3 = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=5, random_state=42, n_jobs=-1)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Random Forest : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Support vector machines : Log Loss: 1.04
# Random Forest : Log Loss: 1.20
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.173
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.992
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.388
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.057
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.224
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.626

# %% [markdown]
# **4.7.2.2 Testing the model with best hyper parameters**

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.4670766188401517
# Log loss (CV) on the stacking classifier : 1.0573266423999002
# Log loss (test) on the stacking classifier : 1.1128334460604126
# Number of missclassified point : 0.3548872180451128
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 4.7.3 Stacking Models [NB, LR, RF]

# %% [markdown]
# **4.7.3.1 Tuning the Hyper Parameters**

# %%
clf1 = SGDClassifier(alpha=0.0001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = MultinomialNB(alpha=0.000001)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

clf3 = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=5, random_state=42, n_jobs=-1)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Random Forest : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Naive Bayes : Log Loss: 1.22
# Random Forest : Log Loss: 1.20
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.174
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.001
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.418
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.089
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.276
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.671

# %% [markdown]
# **4.7.3.2 Testing the model with best Hyper Parameters**

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.4316896094070784
# Log loss (CV) on the stacking classifier : 1.0894595505969193
# Log loss (test) on the stacking classifier : 1.1583893879461522
# Number of missclassified point : 0.38646616541353385
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 4.7.4 Stacking Models [K-NN, NB, Linear]

# %% [markdown]
# **4.7.4.1 Tuning Hyper Parameters**

# %%
clf1 = clf = KNeighborsClassifier(n_neighbors=11)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.0001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

clf3 = MultinomialNB(alpha=0.000001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("K-NN :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# K-NN :  Log Loss: 1.20
# Support vector machines : Log Loss: 1.05
# Naive Bayes : Log Loss: 1.22
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.176
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.014
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.444
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.091
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.235
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.629

# %% [markdown]
# **4.7.4.2 Testing the model with best Hyper Parameters**

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.4400721716374803
# Log loss (CV) on the stacking classifier : 1.0907963489412063
# Log loss (test) on the stacking classifier : 1.169091274537586
# Number of missclassified point : 0.39398496240601505
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 4.7.5 Stacking Models [LR,K-NN,LINEAR]

# %% [markdown]
# **4.7.5.1 Tuning the Hyper Parameters**

# %%
clf1 = SGDClassifier(alpha=0.0001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.0001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

clf3 = KNeighborsClassifier(n_neighbors=11)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("K-NN : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Support vector machines : Log Loss: 1.05
# K-NN : Log Loss: 1.20
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.173
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.991
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.381
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.061
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.259
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.728

# %% [markdown]
# **4.7.5.2 Testing the model with best Hyper Parameters**

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.42867897724395226
# Log loss (CV) on the stacking classifier : 1.060569063714
# Log loss (test) on the stacking classifier : 1.1313267707035475
# Number of missclassified point : 0.35639097744360904
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 4.7.6 Stacking Models [Logistic & Linear]

# %% [markdown]
# **4.7.6.1 Tuning the Hyper Parameters**

# %%
clf1 = SGDClassifier(alpha=0.0001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.0001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))

print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 0.99
# Support vector machines : Log Loss: 1.05
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.177
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.017
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.423
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.072
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.264
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.743

# %% [markdown]
# **4.7.6.2 Testing the model with best Hyper Parameters**

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.4375024285454772
# Log loss (CV) on the stacking classifier : 1.0723381954959692
# Log loss (test) on the stacking classifier : 1.1353107772428408
# Number of missclassified point : 0.3473684210526316
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 5 Maximum Voting classifier

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.887025049555495
# Log loss (CV) on the VotingClassifier : 1.0673456863197526
# Log loss (test) on the VotingClassifier : 1.039201476770283
# Number of missclassified point : 0.318796992481203
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 6. Tabular Result

# %%
import pandas as pd
dataframe = pd.DataFrame(
{
    "Maching Learning Model": ['Naive Bayes','KNearest Neighbours','Logistic Regression [class balancing]','Logistic Regression [without class balancing]', 'Support Vector Machines', 'Random Forest [One Hot]', 'Random Forest [Response Coding]', 'Stacking [LR, SVM, NB] with LR', 'Stacking [LR,Linear,RF] with LR', 'Stacking [NB, LR, RF] with LR', 'Stacking [K-NN, NB, Linear] with LR', 'Stacking [LR, K-NN, Linear] with LR', 'Stacking [LR, Linear] with LR', 'Maximum Voting Classifier'],
    "Train (%)": [0.58,0.63,0.45,0.45,0.59,0.87,0.05,0.38,0.46,0.43,0.44,0.42,0.43,0.88],
    "CV (%)": [1.232,1.060,1.026,1.056,1.072,1.191,1.293,1.083,1.057,1.089,1.090,1.060,1.072,1.067],
    "Test (%)": [1.177,1.041,0.943,0.962,0.996,1.135,1.246,1.15,1.112,1.158,1.169,1.131,1.135,1.039],
    "Misclassification (%)": [40.03,37.78,34.39,34.96,35.52,43.23,50.37,36.69,35.48,38.64,39.39,35.63,34.73,31.87],
}

)
dataframe
# Out:
#                            Maching Learning Model  Train (%)  CV (%)  \
# 0                                     Naive Bayes       0.58   1.232
# 1                             KNearest Neighbours       0.63   1.060
# 2           Logistic Regression [class balancing]       0.45   1.026
# 3   Logistic Regression [without class balancing]       0.45   1.056
# 4                         Support Vector Machines       0.59   1.072
# 5                         Random Forest [One Hot]       0.87   1.191
# 6                 Random Forest [Response Coding]       0.05   1.293
# 7                  Stacking [LR, SVM, NB] with LR       0.38   1.083
# 8                 Stacking [LR,Linear,RF] with LR       0.46   1.057
# 9                   Stacking [NB, LR, RF] with LR       0.43   1.089
# 10            Stacking [K-NN, NB, Linear] with LR       0.44   1.090
# 11            Stacking [LR, K-NN, Linear] with LR       0.42   1.060
# 12                  Stacking [LR, Linear] with LR       0.43   1.072
# 13                      Maximum Voting Classifier       0.88   1.067
#
#     Test (%)  Misclassification (%)
# 0      1.177                  40.03
# 1      1.041                  37.78
# 2      0.943                  34.39
# 3      0.962                  34.96
# 4      0.996                  35.52
# 5      1.135                  43.23
# 6      1.246                  50.37
# 7      1.150                  36.69
# 8      1.112                  35.48
# 9      1.158                  38.64
# 10     1.169                  39.39
# 11     1.131                  35.63
# 12     1.135                  34.73
# 13     1.039                  31.87
