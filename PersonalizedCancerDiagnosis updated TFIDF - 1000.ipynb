# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")
from mlxtend.classifier import StackingClassifier
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\Intel\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 192.35705872901613 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.417997955535833
# Log loss on Test Data using Random Model 2.5307396681870906
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 230
# BRCA1     165
# TP53      104
# EGFR       89
# PTEN       79
# BRCA2      75
# KIT        64
# BRAF       58
# ALK        51
# ERBB2      47
# CDKN2A     40
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 230 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(1, 4))
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2852    BRCA2
# 1548      ALK
# 2548    BRCA1
# 2234     PTEN
# 1128      MET
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl2',
#  'atm',
#  'atr',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axin1',
#  'b2m',
#  'bap1',
#  'bard1',
#  'bcl10',
#  'bcl2',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brd4',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'epcam',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fanca',
#  'fat1',
#  'fbxw7',
#  'fgf3',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxo1',
#  'fubp1',
#  'gata3',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'il7r',
#  'jak1',
#  'jak2',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'lats2',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm2',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'myod1',
#  'ncor1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51b',
#  'rad51c',
#  'rad51d',
#  'rad54l',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rit1',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rxra',
#  'setd2',
#  'sf3b1',
#  'shoc2',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf7l2',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vegfa',
#  'vhl',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 230)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.355937987382182
# For values of alpha =  0.0001 The log loss is: 1.1903841286821997
# For values of alpha =  0.001 The log loss is: 1.2258974196043861
# For values of alpha =  0.01 The log loss is: 1.356481421491509
# For values of alpha =  0.1 The log loss is: 1.459248307950246
# For values of alpha =  1 The log loss is: 1.4982552955967454
# For values of best alpha =  0.0001 The train log loss is: 1.0285262370341544
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1903841286821997
# For values of best alpha =  0.0001 The test log loss is: 1.2478848105929452

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  230  genes in train dataset?
# Ans
# 1. In test data 641 out of 665 : 96.39097744360903
# 2. In cross validation data 519 out of  532 : 97.55639097744361

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1920
# Truncating_Mutations    58
# Deletion                51
# Amplification           46
# Fusions                 22
# Overexpression           4
# T58I                     3
# Q209L                    2
# Q22K                     2
# F28L                     2
# K117N                    2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1920 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02730697 0.05131827 0.07297552 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(1, 4))
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1000)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7432593360034865
# For values of alpha =  0.0001 The log loss is: 1.7317545276567643
# For values of alpha =  0.001 The log loss is: 1.7365396719932527
# For values of alpha =  0.01 The log loss is: 1.742388849891366
# For values of alpha =  0.1 The log loss is: 1.749213098889369
# For values of alpha =  1 The log loss is: 1.7500650457638707
# For values of best alpha =  0.0001 The train log loss is: 1.2169536774390435
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7317545276567643
# For values of best alpha =  0.0001 The test log loss is: 1.6996950254441303

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1920  genes in test and cross validation data sets?
# Ans
# 1. In test data 70 out of 665 : 10.526315789473683
# 2. In cross validation data 49 out of  532 : 9.210526315789473

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a TfidfVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(1, 4))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({11.75719687098962: 2, 11.652601552346054: 2, 10.400101563768628: 2, 9.239025959628393: 2, 8.833290689721066: 2, 251.14719152105494: 1, 181.9980013230872: 1, 130.35182389232307: 1, 130.26939835838112: 1, 129.53995424320644: 1, 115.39272219607248: 1, 115.15373421553589: 1, 115.08047658554722: 1, 114.77805197436469: 1, 110.6827546016392: 1, 104.90577924807965: 1, 100.64739457204023: 1, 89.40955969715473: 1, 88.54694382213388: 1, 86.19560109729044: 1, 79.41289450580962: 1, 79.26285626762362: 1, 77.75271989728999: 1, 77.44449501236988: 1, 77.36006392713676: 1, 77.28237090522072: 1, 77.22937874168744: 1, 73.14883767713077: 1, 69.51428485549998: 1, 68.7010874302974: 1, 68.3372514223002: 1, 66.14135269717431: 1, 65.89304373362086: 1, 65.61550136634176: 1, 63.798234599095984: 1, 63.39747784017624: 1, 63.10530424687153: 1, 62.911622505391364: 1, 61.09510028116901: 1, 60.504139928154515: 1, 59.81098868426579: 1, 58.78348721054754: 1, 57.13740395477657: 1, 55.809081534287714: 1, 55.36258403403448: 1, 52.408022419735985: 1, 52.31792754021165: 1, 50.59198595858811: 1, 49.127320487211094: 1, 48.475784118616744: 1, 47.94425731030281: 1, 47.14563042565628: 1, 45.08544977178073: 1, 45.06070619454756: 1, 45.04626863001601: 1, 44.900429737690516: 1, 44.144829640889654: 1, 43.847717241178515: 1, 43.757251998094475: 1, 43.41678028257654: 1, 42.667311429566276: 1, 42.52606401237269: 1, 42.24502715324869: 1, 42.0068530936523: 1, 41.81168530078102: 1, 41.78444010535431: 1, 41.434595087620224: 1, 41.308295691434985: 1, 41.19182591025833: 1, 41.036742314985304: 1, 40.705647859051616: 1, 40.10538916386603: 1, 39.53956573593311: 1, 39.534024486852545: 1, 39.08027853079509: 1, 39.08008411125056: 1, 38.66296915654524: 1, 38.259486700690516: 1, 38.10995913438597: 1, 37.7209074693463: 1, 37.54121076633029: 1, 37.18387271200359: 1, 37.083320905717954: 1, 36.98266933447427: 1, 36.74340833821305: 1, 35.588141966400755: 1, 35.27567382990037: 1, 35.268969522071565: 1, 35.22093278836768: 1, 34.87724691249528: 1, 34.857298702517866: 1, 34.29554638022843: 1, 34.09703698023385: 1, 34.03948782773171: 1, 33.71775714587138: 1, 33.5448036926822: 1, 33.526772088778124: 1, 33.288118161623906: 1, 33.04800440858617: 1, 32.81954269539484: 1, 32.63020976622828: 1, 32.57259080168563: 1, 32.4076965794167: 1, 32.375108833271085: 1, 32.1582194296535: 1, 32.13412538011498: 1, 32.0408368887113: 1, 31.995740932702358: 1, 31.66349407603636: 1, 31.649488689918073: 1, 31.51715384258025: 1, 31.446212047184048: 1, 31.242466938253987: 1, 31.049983640113123: 1, 31.020861087256236: 1, 30.883916804344903: 1, 30.83363425206399: 1, 30.781375295417927: 1, 30.581315744683828: 1, 30.565120975412476: 1, 30.476146369650618: 1, 30.40176594769974: 1, 30.358356700802272: 1, 30.292508556774393: 1, 30.193143458267386: 1, 30.06274476681565: 1, 29.559174393646202: 1, 29.4999649924469: 1, 29.46085227033804: 1, 29.441268907592214: 1, 29.400290727860128: 1, 29.326604565249042: 1, 29.320796236834816: 1, 29.10933412195447: 1, 28.81786775560343: 1, 28.408193805660147: 1, 28.25335972350524: 1, 28.24994920281708: 1, 28.193689324118225: 1, 28.127690538700676: 1, 27.805584496407988: 1, 27.76363240654139: 1, 27.72925913194902: 1, 27.559900387655315: 1, 27.5199786591909: 1, 27.42833833291257: 1, 27.271809742381265: 1, 27.131559857472375: 1, 27.096521006715776: 1, 27.078907570545628: 1, 26.999661558507988: 1, 26.381267147548208: 1, 26.31470748482093: 1, 26.284320011209783: 1, 26.24004256504631: 1, 26.221211709977972: 1, 26.03409072890766: 1, 25.9115078377949: 1, 25.678761440929073: 1, 25.675759201939847: 1, 25.481263171371328: 1, 25.42579987668686: 1, 25.328102763972826: 1, 25.307747624708412: 1, 25.28958693906801: 1, 25.12173852871046: 1, 24.793391639339784: 1, 24.73533500485351: 1, 24.717949972257493: 1, 24.678506002415297: 1, 24.671296048006415: 1, 24.653988101653457: 1, 24.37569781288602: 1, 24.225197044423506: 1, 24.16043609747745: 1, 24.151813782787993: 1, 24.017366152128584: 1, 23.988136045473084: 1, 23. ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1466015141897483
# For values of alpha =  0.0001 The log loss is: 1.2050623661573248
# For values of alpha =  0.001 The log loss is: 1.5320716286980423
# For values of alpha =  0.01 The log loss is: 2.126467126144793
# For values of alpha =  0.1 The log loss is: 2.135103156720574
# For values of alpha =  1 The log loss is: 2.1058112956175723
# For values of best alpha =  1e-05 The train log loss is: 0.7541594728297089
# For values of best alpha =  1e-05 The cross validation log loss is: 1.1466015141897483
# For values of best alpha =  1e-05 The test log loss is: 1.1819437111862978

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(max_features=1000, ngram_range=(1, 4), min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 94.0 % of word of test data appeared in train data
# 94.1 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000, ngram_range=(1, 4))
    var_count_vec = TfidfVectorizer(max_features=1000, ngram_range=(1, 4))
    text_count_vec = TfidfVectorizer(max_features=1000, ngram_range=(1, 4), min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 2230)
# (number of data points * number of features) in test data =  (665, 2230)
# (number of data points * number of features) in cross validation data = (532, 2230)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2075688552519492
# for alpha = 0.0001
# Log Loss : 1.2080923816898517
# for alpha = 0.001
# Log Loss : 1.207782886379119
# for alpha = 0.1
# Log Loss : 1.194670139174174
# for alpha = 1
# Log Loss : 1.232891572925286
# for alpha = 10
# Log Loss : 1.4004286393588927
# for alpha = 100
# Log Loss : 1.4008823898823766
# for alpha = 1000
# Log Loss : 1.3962824685430815
# For values of best alpha =  0.1 The train log loss is: 0.7870135046710613
# For values of best alpha =  0.1 The cross validation log loss is: 1.194670139174174
# For values of best alpha =  0.1 The test log loss is: 1.2014853141970718

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.194670139174174
# Number of missclassified point : 0.3815789473684211
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0992 0.0399 0.0202 0.7122 0.0364 0.0364 0.0473 0.0047 0.0037]]
# Actual Class : 4
# --------------------------------------------------
# 10 Text feature [activity] present in test data point [True]
# 11 Text feature [protein] present in test data point [True]
# 13 Text feature [proteins] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 18 Text feature [results] present in test data point [True]
# 19 Text feature [shown] present in test data point [True]
# 20 Text feature [whereas] present in test data point [True]
# 21 Text feature [acid] present in test data point [True]
# 22 Text feature [missense] present in test data point [True]
# 23 Text feature [also] present in test data point [True]
# 24 Text feature [amino] present in test data point [True]
# 25 Text feature [two] present in test data point [True]
# 27 Text feature [mutations] present in test data point [True]
# 28 Text feature [determined] present in test data point [True]
# 29 Text feature [type] present in test data point [True]
# 30 Text feature [functional] present in test data point [True]
# 31 Text feature [related] present in test data point [True]
# 32 Text feature [described] present in test data point [True]
# 33 Text feature [may] present in test data point [True]
# 34 Text feature [suppressor] present in test data point [True]
# 35 Text feature [important] present in test data point [True]
# 36 Text feature [whether] present in test data point [True]
# 40 Text feature [wild] present in test data point [True]
# 41 Text feature [although] present in test data point [True]
# 42 Text feature [three] present in test data point [True]
# 43 Text feature [reduced] present in test data point [True]
# 44 Text feature [either] present in test data point [True]
# 45 Text feature [30] present in test data point [True]
# 46 Text feature [thus] present in test data point [True]
# 47 Text feature [determine] present in test data point [True]
# 48 Text feature [vitro] present in test data point [True]
# 49 Text feature [suggesting] present in test data point [True]
# 51 Text feature [mammalian] present in test data point [True]
# 58 Text feature [previously] present in test data point [True]
# 59 Text feature [loss] present in test data point [True]
# 60 Text feature [mutation] present in test data point [True]
# 61 Text feature [discussion] present in test data point [True]
# 62 Text feature [therefore] present in test data point [True]
# 64 Text feature [analysis] present in test data point [True]
# 66 Text feature [similar] present in test data point [True]
# 67 Text feature [levels] present in test data point [True]
# 68 Text feature [show] present in test data point [True]
# 69 Text feature [effects] present in test data point [True]
# 70 Text feature [containing] present in test data point [True]
# 71 Text feature [one] present in test data point [True]
# 72 Text feature [however] present in test data point [True]
# 73 Text feature [indicated] present in test data point [True]
# 74 Text feature [10] present in test data point [True]
# 75 Text feature [associated] present in test data point [True]
# 76 Text feature [functions] present in test data point [True]
# 77 Text feature [vivo] present in test data point [True]
# 78 Text feature [addition] present in test data point [True]
# 79 Text feature [binding] present in test data point [True]
# 80 Text feature [using] present in test data point [True]
# 81 Text feature [several] present in test data point [True]
# 82 Text feature [cycle] present in test data point [True]
# 83 Text feature [lower] present in test data point [True]
# 84 Text feature [suggest] present in test data point [True]
# 87 Text feature [result] present in test data point [True]
# 91 Text feature [expressed] present in test data point [True]
# 92 Text feature [high] present in test data point [True]
# 93 Text feature [cells] present in test data point [True]
# 94 Text feature [possible] present in test data point [True]
# 96 Text feature [reported] present in test data point [True]
# 97 Text feature [acids] present in test data point [True]
# 98 Text feature [consistent] present in test data point [True]
# 99 Text feature [vector] present in test data point [True]
# Out of the top  100  features  67 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.3983 0.0423 0.0181 0.4069 0.0357 0.0388 0.0512 0.0049 0.0039]]
# Actual Class : 4
# --------------------------------------------------
# 10 Text feature [activity] present in test data point [True]
# 11 Text feature [protein] present in test data point [True]
# 13 Text feature [proteins] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 16 Text feature [pten] present in test data point [True]
# 17 Text feature [experiments] present in test data point [True]
# 18 Text feature [results] present in test data point [True]
# 19 Text feature [shown] present in test data point [True]
# 20 Text feature [whereas] present in test data point [True]
# 21 Text feature [acid] present in test data point [True]
# 22 Text feature [missense] present in test data point [True]
# 23 Text feature [also] present in test data point [True]
# 24 Text feature [amino] present in test data point [True]
# 25 Text feature [two] present in test data point [True]
# 27 Text feature [mutations] present in test data point [True]
# 28 Text feature [determined] present in test data point [True]
# 29 Text feature [type] present in test data point [True]
# 30 Text feature [functional] present in test data point [True]
# 31 Text feature [related] present in test data point [True]
# 32 Text feature [described] present in test data point [True]
# 33 Text feature [may] present in test data point [True]
# 34 Text feature [suppressor] present in test data point [True]
# 35 Text feature [important] present in test data point [True]
# 36 Text feature [whether] present in test data point [True]
# 38 Text feature [catalytic] present in test data point [True]
# 40 Text feature [wild] present in test data point [True]
# 41 Text feature [although] present in test data point [True]
# 42 Text feature [three] present in test data point [True]
# 43 Text feature [reduced] present in test data point [True]
# 44 Text feature [either] present in test data point [True]
# 45 Text feature [30] present in test data point [True]
# 46 Text feature [thus] present in test data point [True]
# 47 Text feature [determine] present in test data point [True]
# 48 Text feature [vitro] present in test data point [True]
# 49 Text feature [suggesting] present in test data point [True]
# 50 Text feature [bind] present in test data point [True]
# 51 Text feature [mammalian] present in test data point [True]
# 52 Text feature [indicate] present in test data point [True]
# 58 Text feature [previously] present in test data point [True]
# 59 Text feature [loss] present in test data point [True]
# 60 Text feature [mutation] present in test data point [True]
# 61 Text feature [discussion] present in test data point [True]
# 62 Text feature [therefore] present in test data point [True]
# 63 Text feature [see] present in test data point [True]
# 64 Text feature [analysis] present in test data point [True]
# 65 Text feature [purified] present in test data point [True]
# 66 Text feature [similar] present in test data point [True]
# 67 Text feature [levels] present in test data point [True]
# 68 Text feature [show] present in test data point [True]
# 69 Text feature [effects] present in test data point [True]
# 70 Text feature [containing] present in test data point [True]
# 71 Text feature [one] present in test data point [True]
# 72 Text feature [however] present in test data point [True]
# 73 Text feature [indicated] present in test data point [True]
# 74 Text feature [10] present in test data point [True]
# 75 Text feature [associated] present in test data point [True]
# 76 Text feature [functions] present in test data point [True]
# 77 Text feature [vivo] present in test data point [True]
# 78 Text feature [addition] present in test data point [True]
# 79 Text feature [binding] present in test data point [True]
# 80 Text feature [using] present in test data point [True]
# 81 Text feature [several] present in test data point [True]
# 82 Text feature [cycle] present in test data point [True]
# 83 Text feature [lower] present in test data point [True]
# 84 Text feature [suggest] present in test data point [True]
# 85 Text feature [buffer] present in test data point [True]
# 87 Text feature [result] present in test data point [True]
# 88 Text feature [within] present in test data point [True]
# 89 Text feature [ability] present in test data point [True]
# 90 Text feature [could] present in test data point [True]
# 91 Text feature [expressed] present in test data point [True]
# 92 Text feature [high] present in test data point [True]
# 93 Text feature [cells] present in test data point [True]
# 94 Text feature [possible] present in test data point [True]
# 95 Text feature [analyzed] present in test data point [True]
# 96 Text feature [reported] present in test data point [True]
# 97 Text feature [acids] present in test data point [True]
# 98 Text feature [consistent] present in test data point [True]
# 99 Text feature [vector] present in test data point [True]
# Out of the top  100  features  79 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1143088398960155
# for alpha = 11
# Log Loss : 1.0884911630349723
# for alpha = 15
# Log Loss : 1.0907215255113394
# for alpha = 21
# Log Loss : 1.101590992742562
# for alpha = 31
# Log Loss : 1.09233655610864
# for alpha = 41
# Log Loss : 1.1125477277534266
# for alpha = 51
# Log Loss : 1.122852798683462
# for alpha = 99
# Log Loss : 1.1421769193051612
# For values of best alpha =  11 The train log loss is: 0.6251686771761827
# For values of best alpha =  11 The cross validation log loss is: 1.0884911630349723
# For values of best alpha =  11 The test log loss is: 1.048476467621087

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0884911630349723
# Number of mis-classified points : 0.37593984962406013
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 4
# The  11  nearest neighbours of the test points belongs to classes [4 4 4 4 4 4 4 4 4 4 4]
# Fequency of nearest points : Counter({4: 11})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 4
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [4 4 5 5 4 4 4 4 4 1 4]
# Fequency of nearest points : Counter({4: 8, 5: 2, 1: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1853374804234516
# for alpha = 1e-05
# Log Loss : 1.143372720559069
# for alpha = 0.0001
# Log Loss : 1.0521913501219695
# for alpha = 0.001
# Log Loss : 1.0921311106353897
# for alpha = 0.01
# Log Loss : 1.2431682272873095
# for alpha = 0.1
# Log Loss : 1.6622169768722774
# for alpha = 1
# Log Loss : 1.8102377583664053
# for alpha = 10
# Log Loss : 1.827418869078161
# for alpha = 100
# Log Loss : 1.8294880279512227
# For values of best alpha =  0.0001 The train log loss is: 0.5806772576119267
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0521913501219695
# For values of best alpha =  0.0001 The test log loss is: 1.0654810310577216

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0521913501219695
# Number of mis-classified points : 0.37030075187969924
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0938 0.0318 0.0682 0.6286 0.1335 0.014  0.02   0.0057 0.0045]]
# Actual Class : 4
# --------------------------------------------------
# 32 Text feature [null] present in test data point [True]
# 52 Text feature [families] present in test data point [True]
# 53 Text feature [suppressor] present in test data point [True]
# 58 Text feature [localization] present in test data point [True]
# 77 Text feature [germline] present in test data point [True]
# 81 Text feature [high] present in test data point [True]
# 82 Text feature [protein] present in test data point [True]
# 86 Text feature [show] present in test data point [True]
# 88 Text feature [tumorigenesis] present in test data point [True]
# 97 Text feature [inactivation] present in test data point [True]
# 101 Text feature [suggesting] present in test data point [True]
# 118 Text feature [missense] present in test data point [True]
# 137 Text feature [phenotype] present in test data point [True]
# 168 Text feature [caused] present in test data point [True]
# 194 Text feature [cycle] present in test data point [True]
# 203 Text feature [characterized] present in test data point [True]
# 210 Text feature [changes] present in test data point [True]
# 212 Text feature [bp] present in test data point [True]
# 215 Text feature [relatively] present in test data point [True]
# 220 Text feature [specifically] present in test data point [True]
# 228 Text feature [dna] present in test data point [True]
# 231 Text feature [reduced] present in test data point [True]
# 232 Text feature [differences] present in test data point [True]
# 237 Text feature [tagged] present in test data point [True]
# 240 Text feature [seen] present in test data point [True]
# 248 Text feature [proteins] present in test data point [True]
# 250 Text feature [low] present in test data point [True]
# 258 Text feature [deletion] present in test data point [True]
# 261 Text feature [phosphorylation] present in test data point [True]
# 263 Text feature [represent] present in test data point [True]
# 265 Text feature [lack] present in test data point [True]
# 268 Text feature [stability] present in test data point [True]
# 274 Text feature [mammalian] present in test data point [True]
# 281 Text feature [motif] present in test data point [True]
# 287 Text feature [loss] present in test data point [True]
# 288 Text feature [cause] present in test data point [True]
# 292 Text feature [mrna] present in test data point [True]
# 297 Text feature [normal] present in test data point [True]
# 298 Text feature [despite] present in test data point [True]
# 305 Text feature [context] present in test data point [True]
# 307 Text feature [26] present in test data point [True]
# 308 Text feature [determine] present in test data point [True]
# 312 Text feature [years] present in test data point [True]
# 313 Text feature [considered] present in test data point [True]
# 322 Text feature [29] present in test data point [True]
# 323 Text feature [culture] present in test data point [True]
# 325 Text feature [co] present in test data point [True]
# 327 Text feature [direct] present in test data point [True]
# 330 Text feature [risk] present in test data point [True]
# 332 Text feature [recent] present in test data point [True]
# 334 Text feature [resulting] present in test data point [True]
# 335 Text feature [suggested] present in test data point [True]
# 342 Text feature [nature] present in test data point [True]
# 343 Text feature [suggest] present in test data point [True]
# 344 Text feature [large] present in test data point [True]
# 346 Text feature [functional] present in test data point [True]
# 349 Text feature [genetic] present in test data point [True]
# 351 Text feature [via] present in test data point [True]
# 354 Text feature [investigated] present in test data point [True]
# 358 Text feature [endogenous] present in test data point [True]
# 360 Text feature [regulation] present in test data point [True]
# 361 Text feature [yeast] present in test data point [True]
# 362 Text feature [copy] present in test data point [True]
# 366 Text feature [membrane] present in test data point [True]
# 367 Text feature [lower] present in test data point [True]
# 368 Text feature [approximately] present in test data point [True]
# 372 Text feature [anti] present in test data point [True]
# 375 Text feature [complex] present in test data point [True]
# 377 Text feature [flag] present in test data point [True]
# 385 Text feature [syndrome] present in test data point [True]
# 386 Text feature [relative] present in test data point [True]
# 389 Text feature [tissue] present in test data point [True]
# 394 Text feature [primary] present in test data point [True]
# 397 Text feature [defective] present in test data point [True]
# 398 Text feature [supplementary] present in test data point [True]
# 399 Text feature [staining] present in test data point [True]
# 402 Text feature [detection] present in test data point [True]
# 409 Text feature [key] present in test data point [True]
# 411 Text feature [12] present in test data point [True]
# 412 Text feature [levels] present in test data point [True]
# 421 Text feature [negative] present in test data point [True]
# 422 Text feature [consistent] present in test data point [True]
# 431 Text feature [tumours] present in test data point [True]
# 435 Text feature [individuals] present in test data point [True]
# 436 Text feature [adenocarcinoma] present in test data point [True]
# 445 Text feature [partial] present in test data point [True]
# 448 Text feature [role] present in test data point [True]
# 451 Text feature [42] present in test data point [True]
# 452 Text feature [regions] present in test data point [True]
# 457 Text feature [distribution] present in test data point [True]
# 458 Text feature [splice] present in test data point [True]
# 459 Text feature [strong] present in test data point [True]
# 461 Text feature [3b] present in test data point [True]
# 462 Text feature [domains] present in test data point [True]
# 469 Text feature [deleterious] present in test data point [True]
# 470 Text feature [4a] present in test data point [True]
# 472 Text feature [figure] present in test data point [True]
# 473 Text feature [full] present in test data point [True]
# 474 Text feature [70] present in test data point [True]
# 475 Text feature [involved] present in test data point [True]
# 478 Text feature [frequent] present in test data point [True]
# 482 Text feature [nucleotide] present in test data point [True]
# 485 Text feature [mechanisms] present in test data point [True]
# 490 Text feature [affected] present in test data point [True]
# 493 Text feature [observed] present in test data point [True]
# 494 Text feature [first] present in test data point [True]
# 498 Text feature [strand] present in test data point [True]
# Out of the top  500  features  107 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[2.671e-01 9.300e-03 3.800e-03 5.360e-01 1.112e-01 2.100e-03 5.230e-02
#   1.770e-02 5.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 53 Text feature [suppressor] present in test data point [True]
# 58 Text feature [localization] present in test data point [True]
# 67 Text feature [iii] present in test data point [True]
# 81 Text feature [high] present in test data point [True]
# 82 Text feature [protein] present in test data point [True]
# 83 Text feature [representative] present in test data point [True]
# 86 Text feature [show] present in test data point [True]
# 88 Text feature [tumorigenesis] present in test data point [True]
# 95 Text feature [repair] present in test data point [True]
# 97 Text feature [inactivation] present in test data point [True]
# 101 Text feature [suggesting] present in test data point [True]
# 104 Text feature [tp53] present in test data point [True]
# 118 Text feature [missense] present in test data point [True]
# 129 Text feature [bind] present in test data point [True]
# 134 Text feature [mice] present in test data point [True]
# 137 Text feature [phenotype] present in test data point [True]
# 145 Text feature [family] present in test data point [True]
# 161 Text feature [see] present in test data point [True]
# 168 Text feature [caused] present in test data point [True]
# 171 Text feature [degradation] present in test data point [True]
# 178 Text feature [sds] present in test data point [True]
# 179 Text feature [transfected] present in test data point [True]
# 180 Text feature [nuclear] present in test data point [True]
# 185 Text feature [western] present in test data point [True]
# 186 Text feature [1998] present in test data point [True]
# 194 Text feature [cycle] present in test data point [True]
# 196 Text feature [leads] present in test data point [True]
# 202 Text feature [free] present in test data point [True]
# 203 Text feature [characterized] present in test data point [True]
# 205 Text feature [due] present in test data point [True]
# 207 Text feature [substrate] present in test data point [True]
# 210 Text feature [changes] present in test data point [True]
# 212 Text feature [bp] present in test data point [True]
# 213 Text feature [genome] present in test data point [True]
# 220 Text feature [specifically] present in test data point [True]
# 224 Text feature [decreased] present in test data point [True]
# 225 Text feature [comparison] present in test data point [True]
# 228 Text feature [dna] present in test data point [True]
# 229 Text feature [bound] present in test data point [True]
# 231 Text feature [reduced] present in test data point [True]
# 232 Text feature [differences] present in test data point [True]
# 237 Text feature [tagged] present in test data point [True]
# 238 Text feature [ref] present in test data point [True]
# 240 Text feature [seen] present in test data point [True]
# 242 Text feature [reaction] present in test data point [True]
# 246 Text feature [right] present in test data point [True]
# 248 Text feature [proteins] present in test data point [True]
# 250 Text feature [low] present in test data point [True]
# 256 Text feature [mm] present in test data point [True]
# 258 Text feature [deletion] present in test data point [True]
# 261 Text feature [phosphorylation] present in test data point [True]
# 262 Text feature [particular] present in test data point [True]
# 263 Text feature [represent] present in test data point [True]
# 265 Text feature [lack] present in test data point [True]
# 268 Text feature [stability] present in test data point [True]
# 270 Text feature [min] present in test data point [True]
# 274 Text feature [mammalian] present in test data point [True]
# 275 Text feature [1996] present in test data point [True]
# 276 Text feature [buffer] present in test data point [True]
# 279 Text feature [interact] present in test data point [True]
# 281 Text feature [motif] present in test data point [True]
# 286 Text feature [pattern] present in test data point [True]
# 287 Text feature [loss] present in test data point [True]
# 288 Text feature [cause] present in test data point [True]
# 292 Text feature [mrna] present in test data point [True]
# 293 Text feature [lane] present in test data point [True]
# 294 Text feature [heterozygous] present in test data point [True]
# 295 Text feature [40] present in test data point [True]
# 296 Text feature [rates] present in test data point [True]
# 297 Text feature [normal] present in test data point [True]
# 299 Text feature [kinases] present in test data point [True]
# 305 Text feature [context] present in test data point [True]
# 306 Text feature [indeed] present in test data point [True]
# 307 Text feature [26] present in test data point [True]
# 308 Text feature [determine] present in test data point [True]
# 309 Text feature [times] present in test data point [True]
# 310 Text feature [catalytic] present in test data point [True]
# 313 Text feature [considered] present in test data point [True]
# 314 Text feature [page] present in test data point [True]
# 321 Text feature [ring] present in test data point [True]
# 322 Text feature [29] present in test data point [True]
# 323 Text feature [culture] present in test data point [True]
# 325 Text feature [co] present in test data point [True]
# 326 Text feature [phosphatase] present in test data point [True]
# 327 Text feature [direct] present in test data point [True]
# 330 Text feature [risk] present in test data point [True]
# 332 Text feature [recent] present in test data point [True]
# 334 Text feature [resulting] present in test data point [True]
# 335 Text feature [suggested] present in test data point [True]
# 336 Text feature [difference] present in test data point [True]
# 337 Text feature [require] present in test data point [True]
# 341 Text feature [absence] present in test data point [True]
# 342 Text feature [nature] present in test data point [True]
# 343 Text feature [suggest] present in test data point [True]
# 344 Text feature [large] present in test data point [True]
# 345 Text feature [enhanced] present in test data point [True]
# 346 Text feature [functional] present in test data point [True]
# 347 Text feature [2012] present in test data point [True]
# 349 Text feature [genetic] present in test data point [True]
# 350 Text feature [early] present in test data point [True]
# 351 Text feature [via] present in test data point [True]
# 352 Text feature [nf1] present in test data point [True]
# 353 Text feature [purified] present in test data point [True]
# 354 Text feature [investigated] present in test data point [True]
# 355 Text feature [indicate] present in test data point [True]
# 356 Text feature [length] present in test data point [True]
# 358 Text feature [endogenous] present in test data point [True]
# 359 Text feature [alterations] present in test data point [True]
# 360 Text feature [regulation] present in test data point [True]
# 361 Text feature [yeast] present in test data point [True]
# 365 Text feature [ca] present in test data point [True]
# 366 Text feature [membrane] present in test data point [True]
# 367 Text feature [lower] present in test data point [True]
# 368 Text feature [approximately] present in test data point [True]
# 372 Text feature [anti] present in test data point [True]
# 374 Text feature [elevated] present in test data point [True]
# 375 Text feature [complex] present in test data point [True]
# 377 Text feature [flag] present in test data point [True]
# 382 Text feature [groups] present in test data point [True]
# 386 Text feature [relative] present in test data point [True]
# 389 Text feature [tissue] present in test data point [True]
# 390 Text feature [top] present in test data point [True]
# 393 Text feature [author] present in test data point [True]
# 394 Text feature [primary] present in test data point [True]
# 395 Text feature [1a] present in test data point [True]
# 397 Text feature [defective] present in test data point [True]
# 398 Text feature [supplementary] present in test data point [True]
# 401 Text feature [leukemia] present in test data point [True]
# 402 Text feature [detection] present in test data point [True]
# 403 Text feature [cohort] present in test data point [True]
# 404 Text feature [induced] present in test data point [True]
# 405 Text feature [open] present in test data point [True]
# 408 Text feature [transfection] present in test data point [True]
# 409 Text feature [key] present in test data point [True]
# 411 Text feature [12] present in test data point [True]
# 412 Text feature [levels] present in test data point [True]
# 413 Text feature [gst] present in test data point [True]
# 415 Text feature [number] present in test data point [True]
# 418 Text feature [image] present in test data point [True]
# 421 Text feature [negative] present in test data point [True]
# 422 Text feature [consistent] present in test data point [True]
# 423 Text feature [displayed] present in test data point [True]
# 424 Text feature [embryonic] present in test data point [True]
# 426 Text feature [test] present in test data point [True]
# 428 Text feature [mean] present in test data point [True]
# 429 Text feature [200] present in test data point [True]
# 430 Text feature [standard] present in test data point [True]
# 433 Text feature [correlation] present in test data point [True]
# 438 Text feature [size] present in test data point [True]
# 439 Text feature [invitrogen] present in test data point [True]
# 440 Text feature [without] present in test data point [True]
# 442 Text feature [1999] present in test data point [True]
# 445 Text feature [partial] present in test data point [True]
# 447 Text feature [blot] present in test data point [True]
# 448 Text feature [role] present in test data point [True]
# 450 Text feature [pten] present in test data point [True]
# 451 Text feature [42] present in test data point [True]
# 452 Text feature [regions] present in test data point [True]
# 453 Text feature [demonstrate] present in test data point [True]
# 454 Text feature [rate] present in test data point [True]
# 455 Text feature [day] present in test data point [True]
# 456 Text feature [2009] present in test data point [True]
# 457 Text feature [distribution] present in test data point [True]
# 461 Text feature [3b] present in test data point [True]
# 462 Text feature [domains] present in test data point [True]
# 463 Text feature [37] present in test data point [True]
# 464 Text feature [mg] present in test data point [True]
# 465 Text feature [ubiquitin] present in test data point [True]
# 466 Text feature [spop] present in test data point [True]
# 470 Text feature [4a] present in test data point [True]
# 472 Text feature [figure] present in test data point [True]
# 473 Text feature [full] present in test data point [True]
# 474 Text feature [70] present in test data point [True]
# 475 Text feature [involved] present in test data point [True]
# 478 Text feature [frequent] present in test data point [True]
# 479 Text feature [cellular] present in test data point [True]
# 482 Text feature [nucleotide] present in test data point [True]
# 483 Text feature [experiments] present in test data point [True]
# 484 Text feature [across] present in test data point [True]
# 485 Text feature [mechanisms] present in test data point [True]
# 490 Text feature [affected] present in test data point [True]
# 492 Text feature [1997] present in test data point [True]
# 493 Text feature [observed] present in test data point [True]
# 494 Text feature [first] present in test data point [True]
# 495 Text feature [contact] present in test data point [True]
# 498 Text feature [strand] present in test data point [True]
# Out of the top  500  features  186 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1835555788647625
# for alpha = 1e-05
# Log Loss : 1.1602420045192252
# for alpha = 0.0001
# Log Loss : 1.0713802189812558
# for alpha = 0.001
# Log Loss : 1.1698882666840211
# for alpha = 0.01
# Log Loss : 1.5543865016680496
# for alpha = 0.1
# Log Loss : 1.9343521897504552
# for alpha = 1
# Log Loss : 1.9673403282611812
# For values of best alpha =  0.0001 The train log loss is: 0.5659542565194613
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0713802189812558
# For values of best alpha =  0.0001 The test log loss is: 1.0926849511482073

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0713802189812558
# Number of mis-classified points : 0.37218045112781956
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0933 0.0323 0.0657 0.649  0.1168 0.0141 0.0188 0.0045 0.0054]]
# Actual Class : 4
# --------------------------------------------------
# 36 Text feature [null] present in test data point [True]
# 58 Text feature [high] present in test data point [True]
# 62 Text feature [suppressor] present in test data point [True]
# 66 Text feature [show] present in test data point [True]
# 71 Text feature [tumorigenesis] present in test data point [True]
# 73 Text feature [protein] present in test data point [True]
# 74 Text feature [germline] present in test data point [True]
# 80 Text feature [localization] present in test data point [True]
# 93 Text feature [suggesting] present in test data point [True]
# 94 Text feature [families] present in test data point [True]
# 107 Text feature [inactivation] present in test data point [True]
# 118 Text feature [missense] present in test data point [True]
# 144 Text feature [caused] present in test data point [True]
# 145 Text feature [phenotype] present in test data point [True]
# 148 Text feature [characterized] present in test data point [True]
# 177 Text feature [differences] present in test data point [True]
# 205 Text feature [specifically] present in test data point [True]
# 208 Text feature [cycle] present in test data point [True]
# 214 Text feature [relatively] present in test data point [True]
# 216 Text feature [changes] present in test data point [True]
# 217 Text feature [low] present in test data point [True]
# 220 Text feature [bp] present in test data point [True]
# 229 Text feature [reduced] present in test data point [True]
# 239 Text feature [represent] present in test data point [True]
# 243 Text feature [phosphorylation] present in test data point [True]
# 245 Text feature [dna] present in test data point [True]
# 246 Text feature [seen] present in test data point [True]
# 247 Text feature [suggested] present in test data point [True]
# 255 Text feature [proteins] present in test data point [True]
# 260 Text feature [lack] present in test data point [True]
# 263 Text feature [29] present in test data point [True]
# 264 Text feature [tagged] present in test data point [True]
# 266 Text feature [26] present in test data point [True]
# 268 Text feature [mammalian] present in test data point [True]
# 273 Text feature [endogenous] present in test data point [True]
# 275 Text feature [despite] present in test data point [True]
# 284 Text feature [considered] present in test data point [True]
# 287 Text feature [direct] present in test data point [True]
# 288 Text feature [determine] present in test data point [True]
# 291 Text feature [mrna] present in test data point [True]
# 295 Text feature [suggest] present in test data point [True]
# 296 Text feature [stability] present in test data point [True]
# 299 Text feature [motif] present in test data point [True]
# 302 Text feature [loss] present in test data point [True]
# 312 Text feature [regulation] present in test data point [True]
# 320 Text feature [normal] present in test data point [True]
# 321 Text feature [recent] present in test data point [True]
# 326 Text feature [nature] present in test data point [True]
# 328 Text feature [large] present in test data point [True]
# 330 Text feature [cause] present in test data point [True]
# 332 Text feature [co] present in test data point [True]
# 333 Text feature [deletion] present in test data point [True]
# 335 Text feature [resulting] present in test data point [True]
# 336 Text feature [lower] present in test data point [True]
# 337 Text feature [culture] present in test data point [True]
# 339 Text feature [functional] present in test data point [True]
# 344 Text feature [membrane] present in test data point [True]
# 346 Text feature [anti] present in test data point [True]
# 347 Text feature [defective] present in test data point [True]
# 349 Text feature [context] present in test data point [True]
# 353 Text feature [yeast] present in test data point [True]
# 355 Text feature [key] present in test data point [True]
# 359 Text feature [approximately] present in test data point [True]
# 360 Text feature [risk] present in test data point [True]
# 361 Text feature [via] present in test data point [True]
# 363 Text feature [copy] present in test data point [True]
# 365 Text feature [years] present in test data point [True]
# 368 Text feature [primary] present in test data point [True]
# 374 Text feature [genetic] present in test data point [True]
# 375 Text feature [relative] present in test data point [True]
# 378 Text feature [levels] present in test data point [True]
# 390 Text feature [tissue] present in test data point [True]
# 394 Text feature [detection] present in test data point [True]
# 395 Text feature [syndrome] present in test data point [True]
# 396 Text feature [supplementary] present in test data point [True]
# 398 Text feature [complex] present in test data point [True]
# 399 Text feature [partial] present in test data point [True]
# 401 Text feature [investigated] present in test data point [True]
# 404 Text feature [12] present in test data point [True]
# 407 Text feature [consistent] present in test data point [True]
# 408 Text feature [nucleotide] present in test data point [True]
# 412 Text feature [several] present in test data point [True]
# 414 Text feature [domains] present in test data point [True]
# 419 Text feature [role] present in test data point [True]
# 422 Text feature [frequent] present in test data point [True]
# 424 Text feature [function] present in test data point [True]
# 428 Text feature [observed] present in test data point [True]
# 429 Text feature [figure] present in test data point [True]
# 436 Text feature [adenocarcinoma] present in test data point [True]
# 439 Text feature [tumours] present in test data point [True]
# 440 Text feature [regions] present in test data point [True]
# 442 Text feature [negative] present in test data point [True]
# 443 Text feature [significant] present in test data point [True]
# 444 Text feature [staining] present in test data point [True]
# 445 Text feature [splice] present in test data point [True]
# 449 Text feature [42] present in test data point [True]
# 450 Text feature [rt] present in test data point [True]
# 452 Text feature [3b] present in test data point [True]
# 454 Text feature [flag] present in test data point [True]
# 457 Text feature [first] present in test data point [True]
# 458 Text feature [medium] present in test data point [True]
# 460 Text feature [remains] present in test data point [True]
# 462 Text feature [significantly] present in test data point [True]
# 467 Text feature [45] present in test data point [True]
# 469 Text feature [70] present in test data point [True]
# 478 Text feature [involved] present in test data point [True]
# 479 Text feature [mutation] present in test data point [True]
# 481 Text feature [full] present in test data point [True]
# 482 Text feature [however] present in test data point [True]
# 485 Text feature [mouse] present in test data point [True]
# 488 Text feature [distribution] present in test data point [True]
# 491 Text feature [mechanisms] present in test data point [True]
# 497 Text feature [deleterious] present in test data point [True]
# 498 Text feature [overall] present in test data point [True]
# 499 Text feature [altered] present in test data point [True]
# Out of the top  500  features  115 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2447 0.0065 0.0009 0.5916 0.0515 0.0011 0.0695 0.0342 0.    ]]
# Actual Class : 4
# --------------------------------------------------
# 58 Text feature [high] present in test data point [True]
# 62 Text feature [suppressor] present in test data point [True]
# 66 Text feature [show] present in test data point [True]
# 71 Text feature [tumorigenesis] present in test data point [True]
# 73 Text feature [protein] present in test data point [True]
# 78 Text feature [representative] present in test data point [True]
# 80 Text feature [localization] present in test data point [True]
# 83 Text feature [bind] present in test data point [True]
# 87 Text feature [iii] present in test data point [True]
# 88 Text feature [repair] present in test data point [True]
# 93 Text feature [suggesting] present in test data point [True]
# 97 Text feature [mice] present in test data point [True]
# 107 Text feature [inactivation] present in test data point [True]
# 118 Text feature [missense] present in test data point [True]
# 144 Text feature [caused] present in test data point [True]
# 145 Text feature [phenotype] present in test data point [True]
# 148 Text feature [characterized] present in test data point [True]
# 149 Text feature [tp53] present in test data point [True]
# 151 Text feature [degradation] present in test data point [True]
# 152 Text feature [substrate] present in test data point [True]
# 154 Text feature [leads] present in test data point [True]
# 160 Text feature [family] present in test data point [True]
# 177 Text feature [differences] present in test data point [True]
# 180 Text feature [due] present in test data point [True]
# 182 Text feature [transfected] present in test data point [True]
# 186 Text feature [ref] present in test data point [True]
# 188 Text feature [sds] present in test data point [True]
# 191 Text feature [western] present in test data point [True]
# 193 Text feature [nuclear] present in test data point [True]
# 195 Text feature [free] present in test data point [True]
# 197 Text feature [bound] present in test data point [True]
# 198 Text feature [decreased] present in test data point [True]
# 205 Text feature [specifically] present in test data point [True]
# 207 Text feature [see] present in test data point [True]
# 208 Text feature [cycle] present in test data point [True]
# 213 Text feature [comparison] present in test data point [True]
# 215 Text feature [genome] present in test data point [True]
# 216 Text feature [changes] present in test data point [True]
# 217 Text feature [low] present in test data point [True]
# 220 Text feature [bp] present in test data point [True]
# 222 Text feature [1998] present in test data point [True]
# 229 Text feature [reduced] present in test data point [True]
# 234 Text feature [right] present in test data point [True]
# 239 Text feature [represent] present in test data point [True]
# 240 Text feature [particular] present in test data point [True]
# 243 Text feature [phosphorylation] present in test data point [True]
# 244 Text feature [indeed] present in test data point [True]
# 245 Text feature [dna] present in test data point [True]
# 246 Text feature [seen] present in test data point [True]
# 247 Text feature [suggested] present in test data point [True]
# 255 Text feature [proteins] present in test data point [True]
# 260 Text feature [lack] present in test data point [True]
# 262 Text feature [reaction] present in test data point [True]
# 263 Text feature [29] present in test data point [True]
# 264 Text feature [tagged] present in test data point [True]
# 266 Text feature [26] present in test data point [True]
# 268 Text feature [mammalian] present in test data point [True]
# 270 Text feature [ring] present in test data point [True]
# 271 Text feature [pattern] present in test data point [True]
# 272 Text feature [40] present in test data point [True]
# 273 Text feature [endogenous] present in test data point [True]
# 278 Text feature [difference] present in test data point [True]
# 279 Text feature [catalytic] present in test data point [True]
# 280 Text feature [rates] present in test data point [True]
# 281 Text feature [kinases] present in test data point [True]
# 284 Text feature [considered] present in test data point [True]
# 285 Text feature [elevated] present in test data point [True]
# 287 Text feature [direct] present in test data point [True]
# 288 Text feature [determine] present in test data point [True]
# 291 Text feature [mrna] present in test data point [True]
# 292 Text feature [min] present in test data point [True]
# 294 Text feature [require] present in test data point [True]
# 295 Text feature [suggest] present in test data point [True]
# 296 Text feature [stability] present in test data point [True]
# 299 Text feature [motif] present in test data point [True]
# 300 Text feature [absence] present in test data point [True]
# 302 Text feature [loss] present in test data point [True]
# 308 Text feature [mm] present in test data point [True]
# 312 Text feature [regulation] present in test data point [True]
# 315 Text feature [2012] present in test data point [True]
# 318 Text feature [buffer] present in test data point [True]
# 319 Text feature [nf1] present in test data point [True]
# 320 Text feature [normal] present in test data point [True]
# 321 Text feature [recent] present in test data point [True]
# 322 Text feature [displayed] present in test data point [True]
# 326 Text feature [nature] present in test data point [True]
# 327 Text feature [interact] present in test data point [True]
# 328 Text feature [large] present in test data point [True]
# 330 Text feature [cause] present in test data point [True]
# 332 Text feature [co] present in test data point [True]
# 333 Text feature [deletion] present in test data point [True]
# 334 Text feature [leukemia] present in test data point [True]
# 335 Text feature [resulting] present in test data point [True]
# 336 Text feature [lower] present in test data point [True]
# 337 Text feature [culture] present in test data point [True]
# 339 Text feature [functional] present in test data point [True]
# 340 Text feature [1996] present in test data point [True]
# 341 Text feature [early] present in test data point [True]
# 342 Text feature [enhanced] present in test data point [True]
# 343 Text feature [heterozygous] present in test data point [True]
# 344 Text feature [membrane] present in test data point [True]
# 346 Text feature [anti] present in test data point [True]
# 347 Text feature [defective] present in test data point [True]
# 348 Text feature [correlation] present in test data point [True]
# 349 Text feature [context] present in test data point [True]
# 350 Text feature [induced] present in test data point [True]
# 353 Text feature [yeast] present in test data point [True]
# 354 Text feature [page] present in test data point [True]
# 355 Text feature [key] present in test data point [True]
# 356 Text feature [length] present in test data point [True]
# 357 Text feature [image] present in test data point [True]
# 358 Text feature [author] present in test data point [True]
# 359 Text feature [approximately] present in test data point [True]
# 360 Text feature [risk] present in test data point [True]
# 361 Text feature [via] present in test data point [True]
# 362 Text feature [lane] present in test data point [True]
# 367 Text feature [alterations] present in test data point [True]
# 368 Text feature [primary] present in test data point [True]
# 369 Text feature [times] present in test data point [True]
# 373 Text feature [invitrogen] present in test data point [True]
# 374 Text feature [genetic] present in test data point [True]
# 375 Text feature [relative] present in test data point [True]
# 378 Text feature [levels] present in test data point [True]
# 380 Text feature [phosphatase] present in test data point [True]
# 381 Text feature [cohort] present in test data point [True]
# 382 Text feature [transfection] present in test data point [True]
# 383 Text feature [demonstrate] present in test data point [True]
# 385 Text feature [embryonic] present in test data point [True]
# 386 Text feature [contact] present in test data point [True]
# 387 Text feature [number] present in test data point [True]
# 390 Text feature [tissue] present in test data point [True]
# 391 Text feature [2009] present in test data point [True]
# 392 Text feature [ca] present in test data point [True]
# 393 Text feature [size] present in test data point [True]
# 394 Text feature [detection] present in test data point [True]
# 396 Text feature [supplementary] present in test data point [True]
# 397 Text feature [open] present in test data point [True]
# 398 Text feature [complex] present in test data point [True]
# 399 Text feature [partial] present in test data point [True]
# 400 Text feature [1a] present in test data point [True]
# 401 Text feature [investigated] present in test data point [True]
# 402 Text feature [indicate] present in test data point [True]
# 403 Text feature [1999] present in test data point [True]
# 404 Text feature [12] present in test data point [True]
# 405 Text feature [200] present in test data point [True]
# 406 Text feature [groups] present in test data point [True]
# 407 Text feature [consistent] present in test data point [True]
# 408 Text feature [nucleotide] present in test data point [True]
# 410 Text feature [top] present in test data point [True]
# 412 Text feature [several] present in test data point [True]
# 414 Text feature [domains] present in test data point [True]
# 415 Text feature [ubiquitin] present in test data point [True]
# 416 Text feature [standard] present in test data point [True]
# 417 Text feature [mean] present in test data point [True]
# 419 Text feature [role] present in test data point [True]
# 421 Text feature [purified] present in test data point [True]
# 422 Text feature [frequent] present in test data point [True]
# 424 Text feature [function] present in test data point [True]
# 425 Text feature [experiments] present in test data point [True]
# 427 Text feature [gst] present in test data point [True]
# 428 Text feature [observed] present in test data point [True]
# 429 Text feature [figure] present in test data point [True]
# 430 Text feature [day] present in test data point [True]
# 433 Text feature [test] present in test data point [True]
# 440 Text feature [regions] present in test data point [True]
# 442 Text feature [negative] present in test data point [True]
# 443 Text feature [significant] present in test data point [True]
# 447 Text feature [still] present in test data point [True]
# 448 Text feature [rate] present in test data point [True]
# 449 Text feature [42] present in test data point [True]
# 450 Text feature [rt] present in test data point [True]
# 451 Text feature [blot] present in test data point [True]
# 452 Text feature [3b] present in test data point [True]
# 453 Text feature [across] present in test data point [True]
# 454 Text feature [flag] present in test data point [True]
# 455 Text feature [37] present in test data point [True]
# 456 Text feature [mg] present in test data point [True]
# 457 Text feature [first] present in test data point [True]
# 458 Text feature [medium] present in test data point [True]
# 459 Text feature [notch1] present in test data point [True]
# 460 Text feature [remains] present in test data point [True]
# 461 Text feature [src] present in test data point [True]
# 462 Text feature [significantly] present in test data point [True]
# 466 Text feature [larger] present in test data point [True]
# 467 Text feature [45] present in test data point [True]
# 469 Text feature [70] present in test data point [True]
# 470 Text feature [cellular] present in test data point [True]
# 471 Text feature [spop] present in test data point [True]
# 475 Text feature [hours] present in test data point [True]
# 476 Text feature [without] present in test data point [True]
# 478 Text feature [involved] present in test data point [True]
# 479 Text feature [mutation] present in test data point [True]
# 481 Text feature [full] present in test data point [True]
# 482 Text feature [however] present in test data point [True]
# 485 Text feature [mouse] present in test data point [True]
# 488 Text feature [distribution] present in test data point [True]
# 489 Text feature [similarly] present in test data point [True]
# 491 Text feature [mechanisms] present in test data point [True]
# 494 Text feature [various] present in test data point [True]
# 498 Text feature [overall] present in test data point [True]
# 499 Text feature [altered] present in test data point [True]
# Out of the top  500  features  201 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1445845149498073
# for C = 0.0001
# Log Loss : 1.1051398628798166
# for C = 0.001
# Log Loss : 1.1338673751779933
# for C = 0.01
# Log Loss : 1.3867454225937463
# for C = 0.1
# Log Loss : 1.7281138051074738
# for C = 1
# Log Loss : 1.8300927446634867
# for C = 10
# Log Loss : 1.8300927645986718
# for C = 100
# Log Loss : 1.8300927652957846
# For values of best alpha =  0.0001 The train log loss is: 0.6665919087842265
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1051398628798166
# For values of best alpha =  0.0001 The test log loss is: 1.1259642396344722

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1051398628798166
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1045 0.0444 0.0703 0.4389 0.1969 0.0488 0.0862 0.0057 0.0042]]
# Actual Class : 4
# --------------------------------------------------
# 42 Text feature [null] present in test data point [True]
# 43 Text feature [high] present in test data point [True]
# 44 Text feature [suggesting] present in test data point [True]
# 47 Text feature [suppressor] present in test data point [True]
# 50 Text feature [show] present in test data point [True]
# 51 Text feature [differences] present in test data point [True]
# 52 Text feature [tumorigenesis] present in test data point [True]
# 146 Text feature [protein] present in test data point [True]
# 147 Text feature [phosphorylation] present in test data point [True]
# 149 Text feature [germline] present in test data point [True]
# 153 Text feature [characterized] present in test data point [True]
# 159 Text feature [localization] present in test data point [True]
# 160 Text feature [low] present in test data point [True]
# 161 Text feature [29] present in test data point [True]
# 163 Text feature [families] present in test data point [True]
# 168 Text feature [caused] present in test data point [True]
# 169 Text feature [relatively] present in test data point [True]
# 172 Text feature [inactivation] present in test data point [True]
# 176 Text feature [missense] present in test data point [True]
# 177 Text feature [approximately] present in test data point [True]
# 182 Text feature [specifically] present in test data point [True]
# 184 Text feature [changes] present in test data point [True]
# 186 Text feature [direct] present in test data point [True]
# 188 Text feature [co] present in test data point [True]
# 189 Text feature [bp] present in test data point [True]
# 192 Text feature [endogenous] present in test data point [True]
# 194 Text feature [suggest] present in test data point [True]
# 197 Text feature [motif] present in test data point [True]
# 201 Text feature [26] present in test data point [True]
# 202 Text feature [stability] present in test data point [True]
# 203 Text feature [phenotype] present in test data point [True]
# 205 Text feature [proteins] present in test data point [True]
# 216 Text feature [large] present in test data point [True]
# 218 Text feature [key] present in test data point [True]
# 220 Text feature [partial] present in test data point [True]
# 221 Text feature [seen] present in test data point [True]
# 224 Text feature [context] present in test data point [True]
# 228 Text feature [12] present in test data point [True]
# 233 Text feature [considered] present in test data point [True]
# 234 Text feature [regulation] present in test data point [True]
# 235 Text feature [determine] present in test data point [True]
# 236 Text feature [genetic] present in test data point [True]
# 330 Text feature [recent] present in test data point [True]
# 334 Text feature [adenocarcinoma] present in test data point [True]
# 335 Text feature [frequent] present in test data point [True]
# 340 Text feature [tissue] present in test data point [True]
# 341 Text feature [suggested] present in test data point [True]
# 343 Text feature [regions] present in test data point [True]
# 345 Text feature [complex] present in test data point [True]
# 346 Text feature [represent] present in test data point [True]
# 349 Text feature [lack] present in test data point [True]
# 351 Text feature [normal] present in test data point [True]
# 353 Text feature [however] present in test data point [True]
# 354 Text feature [functional] present in test data point [True]
# 355 Text feature [first] present in test data point [True]
# 356 Text feature [levels] present in test data point [True]
# 357 Text feature [cycle] present in test data point [True]
# 358 Text feature [observed] present in test data point [True]
# 359 Text feature [splice] present in test data point [True]
# 360 Text feature [able] present in test data point [True]
# 361 Text feature [cause] present in test data point [True]
# 362 Text feature [culture] present in test data point [True]
# 363 Text feature [function] present in test data point [True]
# 365 Text feature [45] present in test data point [True]
# 366 Text feature [via] present in test data point [True]
# 370 Text feature [copy] present in test data point [True]
# 373 Text feature [dna] present in test data point [True]
# 375 Text feature [lower] present in test data point [True]
# 378 Text feature [mrna] present in test data point [True]
# 379 Text feature [negative] present in test data point [True]
# 382 Text feature [primary] present in test data point [True]
# 384 Text feature [sample] present in test data point [True]
# 392 Text feature [resulting] present in test data point [True]
# 395 Text feature [membrane] present in test data point [True]
# 396 Text feature [tumours] present in test data point [True]
# 398 Text feature [42] present in test data point [True]
# 400 Text feature [flag] present in test data point [True]
# 402 Text feature [yet] present in test data point [True]
# 403 Text feature [tagged] present in test data point [True]
# 404 Text feature [mammalian] present in test data point [True]
# 407 Text feature [significant] present in test data point [True]
# 408 Text feature [consistent] present in test data point [True]
# 412 Text feature [disease] present in test data point [True]
# 414 Text feature [overall] present in test data point [True]
# 417 Text feature [anti] present in test data point [True]
# 418 Text feature [remains] present in test data point [True]
# 419 Text feature [therefore] present in test data point [True]
# 420 Text feature [rt] present in test data point [True]
# 421 Text feature [relative] present in test data point [True]
# 424 Text feature [nature] present in test data point [True]
# 430 Text feature [specificity] present in test data point [True]
# 431 Text feature [70] present in test data point [True]
# 434 Text feature [expected] present in test data point [True]
# 439 Text feature [likely] present in test data point [True]
# 444 Text feature [medium] present in test data point [True]
# 447 Text feature [conserved] present in test data point [True]
# 448 Text feature [despite] present in test data point [True]
# 450 Text feature [3b] present in test data point [True]
# 451 Text feature [well] present in test data point [True]
# 453 Text feature [positive] present in test data point [True]
# 454 Text feature [deletion] present in test data point [True]
# 455 Text feature [mechanisms] present in test data point [True]
# 456 Text feature [domains] present in test data point [True]
# 457 Text feature [loss] present in test data point [True]
# 458 Text feature [detection] present in test data point [True]
# 459 Text feature [nucleotide] present in test data point [True]
# 462 Text feature [years] present in test data point [True]
# 463 Text feature [strong] present in test data point [True]
# 464 Text feature [determined] present in test data point [True]
# 466 Text feature [several] present in test data point [True]
# 467 Text feature [antibody] present in test data point [True]
# 469 Text feature [residue] present in test data point [True]
# 474 Text feature [per] present in test data point [True]
# 476 Text feature [reduced] present in test data point [True]
# 477 Text feature [among] present in test data point [True]
# 480 Text feature [described] present in test data point [True]
# 485 Text feature [supplementary] present in test data point [True]
# 487 Text feature [defective] present in test data point [True]
# 491 Text feature [manner] present in test data point [True]
# 492 Text feature [figure] present in test data point [True]
# 493 Text feature [48] present in test data point [True]
# 494 Text feature [yeast] present in test data point [True]
# 497 Text feature [investigated] present in test data point [True]
# 498 Text feature [presence] present in test data point [True]
# Out of the top  500  features  124 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1501 0.0121 0.0107 0.6213 0.0719 0.002  0.1205 0.0098 0.0016]]
# Actual Class : 4
# --------------------------------------------------
# 43 Text feature [high] present in test data point [True]
# 44 Text feature [suggesting] present in test data point [True]
# 45 Text feature [mice] present in test data point [True]
# 46 Text feature [representative] present in test data point [True]
# 47 Text feature [suppressor] present in test data point [True]
# 49 Text feature [bind] present in test data point [True]
# 50 Text feature [show] present in test data point [True]
# 51 Text feature [differences] present in test data point [True]
# 52 Text feature [tumorigenesis] present in test data point [True]
# 146 Text feature [protein] present in test data point [True]
# 147 Text feature [phosphorylation] present in test data point [True]
# 151 Text feature [repair] present in test data point [True]
# 152 Text feature [substrate] present in test data point [True]
# 153 Text feature [characterized] present in test data point [True]
# 154 Text feature [comparison] present in test data point [True]
# 155 Text feature [sds] present in test data point [True]
# 157 Text feature [due] present in test data point [True]
# 159 Text feature [localization] present in test data point [True]
# 160 Text feature [low] present in test data point [True]
# 161 Text feature [29] present in test data point [True]
# 162 Text feature [leads] present in test data point [True]
# 165 Text feature [particular] present in test data point [True]
# 166 Text feature [elevated] present in test data point [True]
# 167 Text feature [iii] present in test data point [True]
# 168 Text feature [caused] present in test data point [True]
# 171 Text feature [family] present in test data point [True]
# 172 Text feature [inactivation] present in test data point [True]
# 175 Text feature [pattern] present in test data point [True]
# 176 Text feature [missense] present in test data point [True]
# 177 Text feature [approximately] present in test data point [True]
# 180 Text feature [bound] present in test data point [True]
# 181 Text feature [degradation] present in test data point [True]
# 182 Text feature [specifically] present in test data point [True]
# 183 Text feature [difference] present in test data point [True]
# 184 Text feature [changes] present in test data point [True]
# 185 Text feature [ref] present in test data point [True]
# 186 Text feature [direct] present in test data point [True]
# 187 Text feature [kinases] present in test data point [True]
# 188 Text feature [co] present in test data point [True]
# 189 Text feature [bp] present in test data point [True]
# 190 Text feature [min] present in test data point [True]
# 191 Text feature [transfected] present in test data point [True]
# 192 Text feature [endogenous] present in test data point [True]
# 193 Text feature [40] present in test data point [True]
# 194 Text feature [suggest] present in test data point [True]
# 195 Text feature [enhanced] present in test data point [True]
# 196 Text feature [tp53] present in test data point [True]
# 197 Text feature [motif] present in test data point [True]
# 198 Text feature [1998] present in test data point [True]
# 200 Text feature [correlation] present in test data point [True]
# 201 Text feature [26] present in test data point [True]
# 202 Text feature [stability] present in test data point [True]
# 203 Text feature [phenotype] present in test data point [True]
# 205 Text feature [proteins] present in test data point [True]
# 207 Text feature [free] present in test data point [True]
# 208 Text feature [right] present in test data point [True]
# 209 Text feature [see] present in test data point [True]
# 211 Text feature [rates] present in test data point [True]
# 213 Text feature [leukemia] present in test data point [True]
# 214 Text feature [genome] present in test data point [True]
# 216 Text feature [large] present in test data point [True]
# 217 Text feature [2009] present in test data point [True]
# 218 Text feature [key] present in test data point [True]
# 220 Text feature [partial] present in test data point [True]
# 221 Text feature [seen] present in test data point [True]
# 222 Text feature [2012] present in test data point [True]
# 223 Text feature [western] present in test data point [True]
# 224 Text feature [context] present in test data point [True]
# 226 Text feature [image] present in test data point [True]
# 227 Text feature [nuclear] present in test data point [True]
# 228 Text feature [12] present in test data point [True]
# 229 Text feature [require] present in test data point [True]
# 230 Text feature [indeed] present in test data point [True]
# 231 Text feature [decreased] present in test data point [True]
# 233 Text feature [considered] present in test data point [True]
# 234 Text feature [regulation] present in test data point [True]
# 235 Text feature [determine] present in test data point [True]
# 236 Text feature [genetic] present in test data point [True]
# 330 Text feature [recent] present in test data point [True]
# 331 Text feature [interact] present in test data point [True]
# 333 Text feature [absence] present in test data point [True]
# 335 Text feature [frequent] present in test data point [True]
# 336 Text feature [catalytic] present in test data point [True]
# 337 Text feature [standard] present in test data point [True]
# 338 Text feature [notch1] present in test data point [True]
# 340 Text feature [tissue] present in test data point [True]
# 341 Text feature [suggested] present in test data point [True]
# 342 Text feature [displayed] present in test data point [True]
# 343 Text feature [regions] present in test data point [True]
# 345 Text feature [complex] present in test data point [True]
# 346 Text feature [represent] present in test data point [True]
# 347 Text feature [number] present in test data point [True]
# 348 Text feature [mm] present in test data point [True]
# 349 Text feature [lack] present in test data point [True]
# 351 Text feature [normal] present in test data point [True]
# 352 Text feature [demonstrate] present in test data point [True]
# 353 Text feature [however] present in test data point [True]
# 354 Text feature [functional] present in test data point [True]
# 355 Text feature [first] present in test data point [True]
# 356 Text feature [levels] present in test data point [True]
# 357 Text feature [cycle] present in test data point [True]
# 358 Text feature [observed] present in test data point [True]
# 360 Text feature [able] present in test data point [True]
# 361 Text feature [cause] present in test data point [True]
# 362 Text feature [culture] present in test data point [True]
# 363 Text feature [function] present in test data point [True]
# 364 Text feature [alterations] present in test data point [True]
# 365 Text feature [45] present in test data point [True]
# 366 Text feature [via] present in test data point [True]
# 367 Text feature [heterozygous] present in test data point [True]
# 369 Text feature [1999] present in test data point [True]
# 371 Text feature [reaction] present in test data point [True]
# 373 Text feature [dna] present in test data point [True]
# 375 Text feature [lower] present in test data point [True]
# 376 Text feature [invitrogen] present in test data point [True]
# 377 Text feature [ring] present in test data point [True]
# 378 Text feature [mrna] present in test data point [True]
# 379 Text feature [negative] present in test data point [True]
# 380 Text feature [induced] present in test data point [True]
# 381 Text feature [src] present in test data point [True]
# 382 Text feature [primary] present in test data point [True]
# 384 Text feature [sample] present in test data point [True]
# 385 Text feature [length] present in test data point [True]
# 388 Text feature [gst] present in test data point [True]
# 389 Text feature [experiments] present in test data point [True]
# 390 Text feature [times] present in test data point [True]
# 391 Text feature [early] present in test data point [True]
# 392 Text feature [resulting] present in test data point [True]
# 393 Text feature [carried] present in test data point [True]
# 394 Text feature [37] present in test data point [True]
# 395 Text feature [membrane] present in test data point [True]
# 398 Text feature [42] present in test data point [True]
# 399 Text feature [top] present in test data point [True]
# 400 Text feature [flag] present in test data point [True]
# 402 Text feature [yet] present in test data point [True]
# 403 Text feature [tagged] present in test data point [True]
# 404 Text feature [mammalian] present in test data point [True]
# 405 Text feature [nf1] present in test data point [True]
# 406 Text feature [200] present in test data point [True]
# 407 Text feature [significant] present in test data point [True]
# 408 Text feature [consistent] present in test data point [True]
# 409 Text feature [cohort] present in test data point [True]
# 412 Text feature [disease] present in test data point [True]
# 413 Text feature [60] present in test data point [True]
# 414 Text feature [overall] present in test data point [True]
# 415 Text feature [mean] present in test data point [True]
# 416 Text feature [pocket] present in test data point [True]
# 417 Text feature [anti] present in test data point [True]
# 418 Text feature [remains] present in test data point [True]
# 419 Text feature [therefore] present in test data point [True]
# 420 Text feature [rt] present in test data point [True]
# 421 Text feature [relative] present in test data point [True]
# 422 Text feature [size] present in test data point [True]
# 423 Text feature [open] present in test data point [True]
# 424 Text feature [nature] present in test data point [True]
# 425 Text feature [mg] present in test data point [True]
# 426 Text feature [day] present in test data point [True]
# 427 Text feature [buffer] present in test data point [True]
# 429 Text feature [phospho] present in test data point [True]
# 431 Text feature [70] present in test data point [True]
# 434 Text feature [expected] present in test data point [True]
# 438 Text feature [phosphatase] present in test data point [True]
# 439 Text feature [likely] present in test data point [True]
# 444 Text feature [medium] present in test data point [True]
# 445 Text feature [contact] present in test data point [True]
# 446 Text feature [embryonic] present in test data point [True]
# 447 Text feature [conserved] present in test data point [True]
# 449 Text feature [transfection] present in test data point [True]
# 450 Text feature [3b] present in test data point [True]
# 451 Text feature [well] present in test data point [True]
# 453 Text feature [positive] present in test data point [True]
# 454 Text feature [deletion] present in test data point [True]
# 455 Text feature [mechanisms] present in test data point [True]
# 456 Text feature [domains] present in test data point [True]
# 457 Text feature [loss] present in test data point [True]
# 458 Text feature [detection] present in test data point [True]
# 459 Text feature [nucleotide] present in test data point [True]
# 460 Text feature [hours] present in test data point [True]
# 464 Text feature [determined] present in test data point [True]
# 466 Text feature [several] present in test data point [True]
# 467 Text feature [antibody] present in test data point [True]
# 468 Text feature [various] present in test data point [True]
# 469 Text feature [residue] present in test data point [True]
# 471 Text feature [blot] present in test data point [True]
# 472 Text feature [loop] present in test data point [True]
# 473 Text feature [rate] present in test data point [True]
# 474 Text feature [per] present in test data point [True]
# 475 Text feature [2000] present in test data point [True]
# 476 Text feature [reduced] present in test data point [True]
# 477 Text feature [among] present in test data point [True]
# 478 Text feature [author] present in test data point [True]
# 479 Text feature [without] present in test data point [True]
# 480 Text feature [described] present in test data point [True]
# 481 Text feature [download] present in test data point [True]
# 483 Text feature [apoptosis] present in test data point [True]
# 484 Text feature [still] present in test data point [True]
# 485 Text feature [supplementary] present in test data point [True]
# 486 Text feature [cellular] present in test data point [True]
# 487 Text feature [defective] present in test data point [True]
# 488 Text feature [similarly] present in test data point [True]
# 489 Text feature [larger] present in test data point [True]
# 491 Text feature [manner] present in test data point [True]
# 492 Text feature [figure] present in test data point [True]
# 493 Text feature [48] present in test data point [True]
# 494 Text feature [yeast] present in test data point [True]
# 495 Text feature [eight] present in test data point [True]
# 496 Text feature [groups] present in test data point [True]
# 497 Text feature [investigated] present in test data point [True]
# 498 Text feature [presence] present in test data point [True]
# 499 Text feature [2007] present in test data point [True]
# Out of the top  500  features  210 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.20397863300903
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.231859271016446
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1929654754426067
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2243777831616973
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.1915878891867016
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.218020058433976
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1904605409520561
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2125266038068312
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1889595869458327
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2103037386934679
# For values of best estimator =  2000 The train log loss is: 0.8305294414218297
# For values of best estimator =  2000 The cross validation log loss is: 1.1889595869458325
# For values of best estimator =  2000 The test log loss is: 1.1875327463488288

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1889595869458325
# Number of mis-classified points : 0.40601503759398494
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2337 0.0167 0.0143 0.6025 0.046  0.0399 0.0334 0.0037 0.0099]]
# Actual Class : 4
# --------------------------------------------------
# 3 Text feature [activating] present in test data point [True]
# 4 Text feature [phosphorylation] present in test data point [True]
# 7 Text feature [activation] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [suppressor] present in test data point [True]
# 12 Text feature [constitutive] present in test data point [True]
# 13 Text feature [activated] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 18 Text feature [missense] present in test data point [True]
# 26 Text feature [variants] present in test data point [True]
# 27 Text feature [akt] present in test data point [True]
# 28 Text feature [deleterious] present in test data point [True]
# 29 Text feature [protein] present in test data point [True]
# 31 Text feature [yeast] present in test data point [True]
# 34 Text feature [functional] present in test data point [True]
# 35 Text feature [expression] present in test data point [True]
# 37 Text feature [stability] present in test data point [True]
# 40 Text feature [cells] present in test data point [True]
# 49 Text feature [pathogenic] present in test data point [True]
# 50 Text feature [growth] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 60 Text feature [proteins] present in test data point [True]
# 61 Text feature [defective] present in test data point [True]
# 64 Text feature [ovarian] present in test data point [True]
# 70 Text feature [inactivation] present in test data point [True]
# 71 Text feature [lines] present in test data point [True]
# 73 Text feature [patients] present in test data point [True]
# 76 Text feature [variant] present in test data point [True]
# 77 Text feature [functions] present in test data point [True]
# 84 Text feature [assays] present in test data point [True]
# 85 Text feature [downstream] present in test data point [True]
# 88 Text feature [null] present in test data point [True]
# 90 Text feature [treated] present in test data point [True]
# 93 Text feature [based] present in test data point [True]
# 95 Text feature [sensitivity] present in test data point [True]
# 97 Text feature [predicted] present in test data point [True]
# Out of the top  100  features  36 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.3355 0.1269 0.0169 0.1051 0.0537 0.0469 0.1885 0.0461 0.0803]]
# Actuall Class : 4
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 3 Text feature [activating] present in test data point [True]
# 4 Text feature [phosphorylation] present in test data point [True]
# 7 Text feature [activation] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [suppressor] present in test data point [True]
# 10 Text feature [inhibitors] present in test data point [True]
# 11 Text feature [treatment] present in test data point [True]
# 12 Text feature [constitutive] present in test data point [True]
# 13 Text feature [activated] present in test data point [True]
# 16 Text feature [inhibitor] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 18 Text feature [missense] present in test data point [True]
# 19 Text feature [constitutively] present in test data point [True]
# 21 Text feature [receptor] present in test data point [True]
# 22 Text feature [signaling] present in test data point [True]
# 23 Text feature [oncogenic] present in test data point [True]
# 25 Text feature [activate] present in test data point [True]
# 26 Text feature [variants] present in test data point [True]
# 27 Text feature [akt] present in test data point [True]
# 29 Text feature [protein] present in test data point [True]
# 31 Text feature [yeast] present in test data point [True]
# 32 Text feature [erk] present in test data point [True]
# 34 Text feature [functional] present in test data point [True]
# 35 Text feature [expression] present in test data point [True]
# 37 Text feature [stability] present in test data point [True]
# 38 Text feature [pten] present in test data point [True]
# 40 Text feature [cells] present in test data point [True]
# 41 Text feature [therapy] present in test data point [True]
# 42 Text feature [classified] present in test data point [True]
# 44 Text feature [trials] present in test data point [True]
# 46 Text feature [therapeutic] present in test data point [True]
# 47 Text feature [transforming] present in test data point [True]
# 48 Text feature [neutral] present in test data point [True]
# 50 Text feature [growth] present in test data point [True]
# 52 Text feature [drug] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 54 Text feature [inhibition] present in test data point [True]
# 60 Text feature [proteins] present in test data point [True]
# 61 Text feature [defective] present in test data point [True]
# 62 Text feature [response] present in test data point [True]
# 64 Text feature [ovarian] present in test data point [True]
# 65 Text feature [inhibited] present in test data point [True]
# 67 Text feature [resistance] present in test data point [True]
# 68 Text feature [kinases] present in test data point [True]
# 70 Text feature [inactivation] present in test data point [True]
# 71 Text feature [lines] present in test data point [True]
# 72 Text feature [clinical] present in test data point [True]
# 73 Text feature [patients] present in test data point [True]
# 75 Text feature [phosphorylated] present in test data point [True]
# 76 Text feature [variant] present in test data point [True]
# 77 Text feature [functions] present in test data point [True]
# 78 Text feature [dose] present in test data point [True]
# 82 Text feature [phosphatase] present in test data point [True]
# 83 Text feature [survival] present in test data point [True]
# 84 Text feature [assays] present in test data point [True]
# 85 Text feature [downstream] present in test data point [True]
# 89 Text feature [classification] present in test data point [True]
# 90 Text feature [treated] present in test data point [True]
# 92 Text feature [sensitive] present in test data point [True]
# 93 Text feature [based] present in test data point [True]
# 94 Text feature [ras] present in test data point [True]
# 95 Text feature [sensitivity] present in test data point [True]
# 97 Text feature [predicted] present in test data point [True]
# 99 Text feature [proliferation] present in test data point [True]
# Out of the top  100  features  65 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.1205648920288747
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.8051613897334546
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.661119305588954
# for n_estimators = 10 and max depth =  10
# Log Loss : 2.206200901789743
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.6624138305039133
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.4155388710892782
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.3746950638315667
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.8443841680049977
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5722266526093893
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.442924202797265
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.4794126531325031
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.7772045412250153
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6026977836318774
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.4460302073087214
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.535392522142268
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.8134130440920713
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.6930681487879267
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5230463466017274
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.5152671051831015
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.826569368151954
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.6531950399041988
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5426760015125758
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.5177855529269364
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.814295181442506
# For values of best alpha =  50 The train log loss is: 0.07074711255827329
# For values of best alpha =  50 The cross validation log loss is: 1.3746950638315667
# For values of best alpha =  50 The test log loss is: 1.4043159567448886

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3746950638315667
# Number of mis-classified points : 0.5075187969924813
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0723 0.016  0.1443 0.6104 0.0504 0.0451 0.0045 0.0316 0.0252]]
# Actual Class : 4
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1982 0.0223 0.0999 0.3262 0.1599 0.0862 0.0066 0.0473 0.0533]]
# Actual Class : 4
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.09
# Support vector machines : Log Loss: 1.83
# Naive Bayes : Log Loss: 1.21
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.037
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.523
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.161
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.194
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.291

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.8045152569272356
# Log loss (CV) on the stacking classifier : 1.1605090953620563
# Log loss (test) on the stacking classifier : 1.148021546324785
# Number of missclassified point : 0.37142857142857144
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9425794297751297
# Log loss (CV) on the VotingClassifier : 1.2128145047622834
# Log loss (test) on the VotingClassifier : 1.1928756530806923
# Number of missclassified point : 0.3804511278195489
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 5. Tabular Result

# %%
import pandas as pd
dataframe = pd.DataFrame(
{
    "Maching Learning Model": ['Naive Bayes','K' 'Nearest Neighbours','Logistic Regression [class balancing]','Logistic Regression [without class balancing]', 'Support Vector Machines', 'Random Forest [One Hot]', 'Random Forest [Response Coding]', 'Stacking [LR, SVM, NB] with LR', 'Maximum Voting Classifier'],
    "Train (%)": [0.78,0.62,0.58,0.56,0.66,0.83,0.07,0.80,0.94],
    "CV (%)": [1.19,1.08,1.05,1.07,1.10,1.18,1.37,1.16,1.21],
    "Test (%)": [1.20,1.04,1.06,1.09,1.12,1.18,1.40,1.14,1.19],
    "Misclassification (%)": [38.15,37.59,37.03,37.21,36.65,40.60,50.75,37.14,38.04],
}

)
dataframe
# Out:
#                           Maching Learning Model  Train (%)  CV (%)  Test (%)  \
# 0                                    Naive Bayes       0.78    1.19      1.20
# 1                            KNearest Neighbours       0.62    1.08      1.04
# 2          Logistic Regression [class balancing]       0.58    1.05      1.06
# 3  Logistic Regression [without class balancing]       0.56    1.07      1.09
# 4                        Support Vector Machines       0.66    1.10      1.12
# 5                        Random Forest [One Hot]       0.83    1.18      1.18
# 6                Random Forest [Response Coding]       0.07    1.37      1.40
# 7                 Stacking [LR, SVM, NB] with LR       0.80    1.16      1.14
# 8                      Maximum Voting Classifier       0.94    1.21      1.19
#
#    Misclassification (%)
# 0                  38.15
# 1                  37.59
# 2                  37.03
# 3                  37.21
# 4                  36.65
# 5                  40.60
# 6                  50.75
# 7                  37.14
# 8                  38.04
